# %% [markdown]
# <div style="background-color: #eee3d3">
# <h1> 2-missing_value_imputation.ipynb </h1>
# </div>

# %% [markdown]
# # Missing value imputation with Python
#
# ---
#
# ### The purpose of this notebook is to use different methods to fill the missing values in our peak table :
#
# - __Univariate__ feature imputation
#     - __zero__ (or __one__ or any other constant value to avoid further analytical problems)
#     - __mean__
#     - __median__
#     - __mode__ (most frequent)
#     - __minimum__
#     - __half minimum__
# - __Multivariate__ feature imputation
#     - __MICE__ (inspired by the R <code>MICE</code> package)
# - __KNN imputation__
#
#
# These methods come from the scikitlearn documentation : [cf. doc scikitlearn](https://scikit-learn.org/stable/modules/impute.html#marking-imputed-values)
#
# One type of imputation algorithm is __univariate__, which imputes values in the i-th feature dimension __using only non-missing values in that feature dimension__ (e.g. <code>impute.SimpleImputer</code>). By contrast, __multivariate__ imputation algorithms __use the entire set of available feature dimensions__ to estimate the missing values (e.g. <code>impute.IterativeImputer</code>).
#
# ---
#
# ### The scikitlearn <code>IterativeImputer</code> is still experimental, so we will also use directly the R <code>MICE</code> package ([documentation](https://www.rdocumentation.org/packages/mice/versions/3.13.0/topics/mice)) using the scripts in _bin/missing_value_imputation_ subfolder
#
# ---

# %% [markdown]
# # Import modules

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import random
import numpy as np
import sklearn
import math

# %%
import os
import sys
sys.path.append('/'.join(os.getcwd().split('/')[:-1]) + '/bin/')

from missing_value_imputation_functions import *

# %% [markdown]
# # Import data

# %%
path_peakTable = '/'.join(os.getcwd().split('/')[:-1]) + '/data/peakTable/original_peak_table/peakTable_HILIC_POS.csv'
peakTable_HILIC_POS = pd.read_csv(path_peakTable, sep=',', decimal='.', na_values='NA')
peakTable_HILIC_POS

# Original peak table
# Out:
#        SampleID    Groups  MatchCaseset   TypTumo CaseHCCWide  variable_3  \
# 0    LivCan_153  Incident            82       HCC         Yes   19.761786
# 1    LivCan_154  Non-case            82       NaN          No   19.735279
# 2    LivCan_267  Incident           427       HCC         Yes   19.116076
# 3    LivCan_268  Non-case           427       NaN          No   19.376875
# 4    LivCan_299  Incident           376  HCC_Wide         Yes   19.555938
# ..          ...       ...           ...       ...         ...         ...
# 181  LivCan_080  Non-case            56       NaN          No   19.664978
# 182  LivCan_375  Incident           383       HCC         Yes   19.301954
# 183  LivCan_376  Non-case           383       NaN          No   19.170626
# 184  LivCan_165  Incident           147       HCC         Yes   18.869505
# 185  LivCan_166  Non-case           147       NaN          No   18.954904
#
#      variable_5  variable_6  variable_7  variable_8  ...  variable_2339  \
# 0     14.635833   22.185582   16.414744   12.615143  ...      12.052252
# 1     15.193396   20.831414   15.052533         NaN  ...      13.020365
# 2     15.446714   22.152604   16.410827         NaN  ...            NaN
# 3     15.460525   22.169389   16.403964   12.720767  ...            NaN
# 4     14.515536   22.150249   16.372219   12.314019  ...            NaN
# ..          ...         ...         ...         ...  ...            ...
# 181   14.447858   20.808503   15.027154   12.648327  ...      12.349299
# 182   14.839941   21.085175   15.321075   12.510670  ...      12.909283
# 183   14.291711   21.381912   15.197205   12.499558  ...      12.846355
# 184   14.440576   20.961485   14.829978   12.312338  ...      12.477753
# 185         NaN   20.005032         NaN   12.414258  ...      13.225899
#
#      variable_2340  variable_2350  variable_2353  variable_2364  \
# 0        12.568647      13.192848      13.230752      12.248590
# 1        12.928643      13.697314            NaN      12.604052
# 2              NaN            NaN      13.330175            NaN
# 3              NaN      13.086805      13.304171            NaN
# 4              NaN            NaN      13.306722      12.349830
# ..             ...            ...            ...            ...
# 181      11.505004      13.189121            NaN            NaN
# 182      12.642143            NaN            NaN      12.708850
# 183      13.243400            NaN            NaN      12.199647
# 184      11.789382            NaN            NaN      11.628154
# 185      12.978890      11.596877            NaN            NaN
#
#      variable_2365  variable_2368  variable_2370  variable_2375  variable_2379
# 0        12.114328      14.269258      12.355017      13.114289      13.882526
# 1              NaN            NaN      12.208084            NaN            NaN
# 2              NaN      14.215988            NaN      12.955618      13.778398
# 3        11.605353      14.284148      12.319119      13.058285      13.812829
# 4        11.926237      14.192775            NaN      13.006556      13.841201
# ..             ...            ...            ...            ...            ...
# 181            NaN            NaN            NaN            NaN            NaN
# 182      12.462751      12.175110      12.635066            NaN            NaN
# 183            NaN            NaN      12.258149            NaN            NaN
# 184            NaN            NaN            NaN            NaN            NaN
# 185            NaN            NaN      12.158923            NaN            NaN
#
# [186 rows x 562 columns]

# %%
peakTable_HILIC_POS.head(15)
# Out:
#       SampleID    Groups  MatchCaseset   TypTumo CaseHCCWide  variable_3  \
# 0   LivCan_153  Incident            82       HCC         Yes   19.761786
# 1   LivCan_154  Non-case            82       NaN          No   19.735279
# 2   LivCan_267  Incident           427       HCC         Yes   19.116076
# 3   LivCan_268  Non-case           427       NaN          No   19.376875
# 4   LivCan_299  Incident           376  HCC_Wide         Yes   19.555938
# 5   LivCan_300  Non-case           376       NaN          No   19.377437
# 6   LivCan_085  Non-case            28       NaN          No   19.526568
# 7   LivCan_086  Incident            28       HCC         Yes   19.349326
# 8   LivCan_309  Incident            48       HCC         Yes   19.610237
# 9   LivCan_310  Non-case            48       NaN          No   19.409257
# 10  LivCan_305  Non-case           501       NaN          No   19.458986
# 11  LivCan_306  Incident           501  HCC_Wide         Yes   19.417123
# 12  LivCan_263  Incident            86       HCC         Yes   19.456756
# 13  LivCan_264  Non-case            86       NaN          No   19.793048
# 14  LivCan_013  Incident            94       HCC         Yes   19.452272
#
#     variable_5  variable_6  variable_7  variable_8  ...  variable_2339  \
# 0    14.635833   22.185582   16.414744   12.615143  ...      12.052252
# 1    15.193396   20.831414   15.052533         NaN  ...      13.020365
# 2    15.446714   22.152604   16.410827         NaN  ...            NaN
# 3    15.460525   22.169389   16.403964   12.720767  ...            NaN
# 4    14.515536   22.150249   16.372219   12.314019  ...            NaN
# 5    14.913215   22.198844   16.428678         NaN  ...            NaN
# 6    14.648653   22.092599   16.311085   12.472396  ...      12.551415
# 7    14.454301   22.093306   16.302336         NaN  ...            NaN
# 8    14.713504   22.006737   16.196649   12.438756  ...            NaN
# 9    14.916472   22.122923   16.322582   12.698220  ...      12.053509
# 10   14.715541   22.188102   16.412098   12.680790  ...      12.464260
# 11   14.546802   22.152231   16.360201         NaN  ...      11.716583
# 12   14.569469   22.126302   16.301957   12.399680  ...            NaN
# 13   14.737229   22.201186   16.404767   12.802906  ...            NaN
# 14   15.067445   21.795735   16.079068   12.696082  ...      13.606699
#
#     variable_2340  variable_2350  variable_2353  variable_2364  variable_2365  \
# 0       12.568647      13.192848      13.230752      12.248590      12.114328
# 1       12.928643      13.697314            NaN      12.604052            NaN
# 2             NaN            NaN      13.330175            NaN            NaN
# 3             NaN      13.086805      13.304171            NaN      11.605353
# 4             NaN            NaN      13.306722      12.349830      11.926237
# 5             NaN            NaN      13.468376      12.553141            NaN
# 6       12.590466      12.046802      13.257812            NaN      11.967111
# 7             NaN            NaN      13.167145      12.423250      11.645077
# 8             NaN      13.772616      13.126853      12.559007            NaN
# 9             NaN      13.580326      13.283324            NaN            NaN
# 10      12.766416      12.060652      13.446875      11.996045      12.320520
# 11            NaN      13.941537      13.301791      11.718316      11.610224
# 12            NaN      13.024862      13.300254            NaN            NaN
# 13            NaN            NaN      13.356136            NaN            NaN
# 14      12.903134      12.337137      12.911013      12.641051      12.226943
#
#     variable_2368  variable_2370  variable_2375  variable_2379
# 0       14.269258      12.355017      13.114289      13.882526
# 1             NaN      12.208084            NaN            NaN
# 2       14.215988            NaN      12.955618      13.778398
# 3       14.284148      12.319119      13.058285      13.812829
# 4       14.192775            NaN      13.006556      13.841201
# 5       14.353224            NaN      13.006797      13.968235
# 6       14.068035            NaN      13.015433      13.797054
# 7       14.090122            NaN      12.939756      13.582338
# 8       14.176808      11.652428      12.983154      13.672213
# 9       14.172761            NaN      12.929704      13.798821
# 10      14.368564      12.047480            NaN      13.979732
# 11      14.141841            NaN      13.053946      13.874695
# 12      14.163230            NaN      12.949132      13.844655
# 13      14.264617            NaN      13.062456      13.974848
# 14      13.787496            NaN      12.479307      13.272192
#
# [15 rows x 562 columns]

# %%
peakTable_HILIC_POS['TypTumo'].value_counts()
# Out:
# HCC         80
# HCC_Wide    13
# Name: TypTumo, dtype: int64

# %%
X = peakTable_HILIC_POS.iloc[:, ['variable' in col for col in peakTable_HILIC_POS.columns]]
X

# X is a subset containing only 'variables' so the compounds (metabolites)
# Out:
#      variable_3  variable_5  variable_6  variable_7  variable_8  variable_10  \
# 0     19.761786   14.635833   22.185582   16.414744   12.615143    15.580604
# 1     19.735279   15.193396   20.831414   15.052533         NaN    15.145423
# 2     19.116076   15.446714   22.152604   16.410827         NaN    14.628890
# 3     19.376875   15.460525   22.169389   16.403964   12.720767    15.937169
# 4     19.555938   14.515536   22.150249   16.372219   12.314019    14.950203
# ..          ...         ...         ...         ...         ...          ...
# 181   19.664978   14.447858   20.808503   15.027154   12.648327    14.806952
# 182   19.301954   14.839941   21.085175   15.321075   12.510670    14.488147
# 183   19.170626   14.291711   21.381912   15.197205   12.499558    14.434959
# 184   18.869505   14.440576   20.961485   14.829978   12.312338    14.114074
# 185   18.954904         NaN   20.005032         NaN   12.414258          NaN
#
#      variable_11  variable_14  variable_22  variable_23  ...  variable_2339  \
# 0      15.881437    17.500899    12.792893    16.805604  ...      12.052252
# 1      14.034654    17.953780          NaN    15.907714  ...      13.020365
# 2      15.316772    17.404715    12.786407    15.947176  ...            NaN
# 3      15.967749    15.836957          NaN    16.371211  ...            NaN
# 4      15.294906    16.610171    12.214057    16.171763  ...            NaN
# ..           ...          ...          ...          ...  ...            ...
# 181    14.244917    17.126579    12.080710    15.388376  ...      12.349299
# 182    15.163197    16.816591    12.452644    16.474456  ...      12.909283
# 183    14.520558    16.315887    12.808417    15.613263  ...      12.846355
# 184    13.776358    16.110117    12.667428    16.021372  ...      12.477753
# 185          NaN    15.432975    12.047361    15.443640  ...      13.225899
#
#      variable_2340  variable_2350  variable_2353  variable_2364  \
# 0        12.568647      13.192848      13.230752      12.248590
# 1        12.928643      13.697314            NaN      12.604052
# 2              NaN            NaN      13.330175            NaN
# 3              NaN      13.086805      13.304171            NaN
# 4              NaN            NaN      13.306722      12.349830
# ..             ...            ...            ...            ...
# 181      11.505004      13.189121            NaN            NaN
# 182      12.642143            NaN            NaN      12.708850
# 183      13.243400            NaN            NaN      12.199647
# 184      11.789382            NaN            NaN      11.628154
# 185      12.978890      11.596877            NaN            NaN
#
#      variable_2365  variable_2368  variable_2370  variable_2375  variable_2379
# 0        12.114328      14.269258      12.355017      13.114289      13.882526
# 1              NaN            NaN      12.208084            NaN            NaN
# 2              NaN      14.215988            NaN      12.955618      13.778398
# 3        11.605353      14.284148      12.319119      13.058285      13.812829
# 4        11.926237      14.192775            NaN      13.006556      13.841201
# ..             ...            ...            ...            ...            ...
# 181            NaN            NaN            NaN            NaN            NaN
# 182      12.462751      12.175110      12.635066            NaN            NaN
# 183            NaN            NaN      12.258149            NaN            NaN
# 184            NaN            NaN            NaN            NaN            NaN
# 185            NaN            NaN      12.158923            NaN            NaN
#
# [186 rows x 557 columns]

# %%
plt.figure(figsize=(15,8))
sns.heatmap(X.notna(), cbar=False)
plt.show()

# %% [markdown]
# The dark points indicate a missing value in the peak table

# %%
number_na = X.isna().sum().sum() # Number of na in X
number_na
# Out:
# 13610

# %%
number_value = X.notna().sum().sum() # Number of not na in X
number_value
# Out:
# 89992

# %%
number_na/(number_na+number_value)*100 # % of Na values
# Out:
# 13.13681203065578

# %%
plt.figure(figsize=(16,10))
plt.plot((X.isna().sum() / X.shape[0]).sort_values().values, color='b', linewidth=3)
plt.xlabel('N° of the compound', fontsize=12)
plt.ylabel('Part of samples missing the compound', fontsize=12)
plt.title('The part of samples missing each compound', fontsize=18)
plt.grid(linestyle='--', linewidth=1)
plt.show()

# %%
(X.isna().sum()/X.shape[0]).sort_values()[:157] # values plot in the figure above
# Out:
# variable_3      0.0
# variable_950    0.0
# variable_953    0.0
# variable_957    0.0
# variable_990    0.0
#                ...
# variable_377    0.0
# variable_14     0.0
# variable_165    0.0
# variable_212    0.0
# variable_87     0.0
# Length: 157, dtype: float64

# %%
peakTable_HILIC_POS['variable_1591'].isna().sum()
# Out:
# 92

# %% [markdown]
# # Path to save imputed peak tables

# %%
path_peakTable_imputed = '/'.join(os.getcwd().split('/')[:-1]) + '/data/peakTable/imputed_peak_tables/'

# %% [markdown]
# # Univariate feature imputation

# %% [markdown]
# ## Constant imputation (with whatever constant value passed as argument)
#
# All missing values in the peak table will be replaced by the constant value you pass as parameter.

# %%
X_const_0 = const_imputer(X)
X_const_0.to_csv(path_peakTable_imputed + 'X_const_0.csv', index = False, header=True)
X_const_0
# Out:
#      variable_3  variable_5  variable_6  variable_7  variable_8  variable_10  \
# 0     19.761786   14.635833   22.185582   16.414744   12.615143    15.580604
# 1     19.735279   15.193396   20.831414   15.052533    0.000000    15.145423
# 2     19.116076   15.446714   22.152604   16.410827    0.000000    14.628890
# 3     19.376875   15.460525   22.169389   16.403964   12.720767    15.937169
# 4     19.555938   14.515536   22.150249   16.372219   12.314019    14.950203
# ..          ...         ...         ...         ...         ...          ...
# 181   19.664978   14.447858   20.808503   15.027154   12.648327    14.806952
# 182   19.301954   14.839941   21.085175   15.321075   12.510670    14.488147
# 183   19.170626   14.291711   21.381912   15.197205   12.499558    14.434959
# 184   18.869505   14.440576   20.961485   14.829978   12.312338    14.114074
# 185   18.954904    0.000000   20.005032    0.000000   12.414258     0.000000
#
#      variable_11  variable_14  variable_22  variable_23  ...  variable_2339  \
# 0      15.881437    17.500899    12.792893    16.805604  ...      12.052252
# 1      14.034654    17.953780     0.000000    15.907714  ...      13.020365
# 2      15.316772    17.404715    12.786407    15.947176  ...       0.000000
# 3      15.967749    15.836957     0.000000    16.371211  ...       0.000000
# 4      15.294906    16.610171    12.214057    16.171763  ...       0.000000
# ..           ...          ...          ...          ...  ...            ...
# 181    14.244917    17.126579    12.080710    15.388376  ...      12.349299
# 182    15.163197    16.816591    12.452644    16.474456  ...      12.909283
# 183    14.520558    16.315887    12.808417    15.613263  ...      12.846355
# 184    13.776358    16.110117    12.667428    16.021372  ...      12.477753
# 185     0.000000    15.432975    12.047361    15.443640  ...      13.225899
#
#      variable_2340  variable_2350  variable_2353  variable_2364  \
# 0        12.568647      13.192848      13.230752      12.248590
# 1        12.928643      13.697314       0.000000      12.604052
# 2         0.000000       0.000000      13.330175       0.000000
# 3         0.000000      13.086805      13.304171       0.000000
# 4         0.000000       0.000000      13.306722      12.349830
# ..             ...            ...            ...            ...
# 181      11.505004      13.189121       0.000000       0.000000
# 182      12.642143       0.000000       0.000000      12.708850
# 183      13.243400       0.000000       0.000000      12.199647
# 184      11.789382       0.000000       0.000000      11.628154
# 185      12.978890      11.596877       0.000000       0.000000
#
#      variable_2365  variable_2368  variable_2370  variable_2375  variable_2379
# 0        12.114328      14.269258      12.355017      13.114289      13.882526
# 1         0.000000       0.000000      12.208084       0.000000       0.000000
# 2         0.000000      14.215988       0.000000      12.955618      13.778398
# 3        11.605353      14.284148      12.319119      13.058285      13.812829
# 4        11.926237      14.192775       0.000000      13.006556      13.841201
# ..             ...            ...            ...            ...            ...
# 181       0.000000       0.000000       0.000000       0.000000       0.000000
# 182      12.462751      12.175110      12.635066       0.000000       0.000000
# 183       0.000000       0.000000      12.258149       0.000000       0.000000
# 184       0.000000       0.000000       0.000000       0.000000       0.000000
# 185       0.000000       0.000000      12.158923       0.000000       0.000000
#
# [186 rows x 557 columns]

# %%
X_const_1 = const_imputer(X, 1)
X_const_1.to_csv(path_peakTable_imputed + 'X_const_1.csv', index = False, header=True)
X_const_1
# Out:
#      variable_3  variable_5  variable_6  variable_7  variable_8  variable_10  \
# 0     19.761786   14.635833   22.185582   16.414744   12.615143    15.580604
# 1     19.735279   15.193396   20.831414   15.052533    1.000000    15.145423
# 2     19.116076   15.446714   22.152604   16.410827    1.000000    14.628890
# 3     19.376875   15.460525   22.169389   16.403964   12.720767    15.937169
# 4     19.555938   14.515536   22.150249   16.372219   12.314019    14.950203
# ..          ...         ...         ...         ...         ...          ...
# 181   19.664978   14.447858   20.808503   15.027154   12.648327    14.806952
# 182   19.301954   14.839941   21.085175   15.321075   12.510670    14.488147
# 183   19.170626   14.291711   21.381912   15.197205   12.499558    14.434959
# 184   18.869505   14.440576   20.961485   14.829978   12.312338    14.114074
# 185   18.954904    1.000000   20.005032    1.000000   12.414258     1.000000
#
#      variable_11  variable_14  variable_22  variable_23  ...  variable_2339  \
# 0      15.881437    17.500899    12.792893    16.805604  ...      12.052252
# 1      14.034654    17.953780     1.000000    15.907714  ...      13.020365
# 2      15.316772    17.404715    12.786407    15.947176  ...       1.000000
# 3      15.967749    15.836957     1.000000    16.371211  ...       1.000000
# 4      15.294906    16.610171    12.214057    16.171763  ...       1.000000
# ..           ...          ...          ...          ...  ...            ...
# 181    14.244917    17.126579    12.080710    15.388376  ...      12.349299
# 182    15.163197    16.816591    12.452644    16.474456  ...      12.909283
# 183    14.520558    16.315887    12.808417    15.613263  ...      12.846355
# 184    13.776358    16.110117    12.667428    16.021372  ...      12.477753
# 185     1.000000    15.432975    12.047361    15.443640  ...      13.225899
#
#      variable_2340  variable_2350  variable_2353  variable_2364  \
# 0        12.568647      13.192848      13.230752      12.248590
# 1        12.928643      13.697314       1.000000      12.604052
# 2         1.000000       1.000000      13.330175       1.000000
# 3         1.000000      13.086805      13.304171       1.000000
# 4         1.000000       1.000000      13.306722      12.349830
# ..             ...            ...            ...            ...
# 181      11.505004      13.189121       1.000000       1.000000
# 182      12.642143       1.000000       1.000000      12.708850
# 183      13.243400       1.000000       1.000000      12.199647
# 184      11.789382       1.000000       1.000000      11.628154
# 185      12.978890      11.596877       1.000000       1.000000
#
#      variable_2365  variable_2368  variable_2370  variable_2375  variable_2379
# 0        12.114328      14.269258      12.355017      13.114289      13.882526
# 1         1.000000       1.000000      12.208084       1.000000       1.000000
# 2         1.000000      14.215988       1.000000      12.955618      13.778398
# 3        11.605353      14.284148      12.319119      13.058285      13.812829
# 4        11.926237      14.192775       1.000000      13.006556      13.841201
# ..             ...            ...            ...            ...            ...
# 181       1.000000       1.000000       1.000000       1.000000       1.000000
# 182      12.462751      12.175110      12.635066       1.000000       1.000000
# 183       1.000000       1.000000      12.258149       1.000000       1.000000
# 184       1.000000       1.000000       1.000000       1.000000       1.000000
# 185       1.000000       1.000000      12.158923       1.000000       1.000000
#
# [186 rows x 557 columns]

# %%
# Not so good, it creates BIG bias

# %% [markdown]
# ## Mean imputation
#
# For each feature, the missing values are imputed by the mean value of the non-missing values in that feature.

# %%
X_mean = mean_imputer(X)
X_mean.to_csv(path_peakTable_imputed + 'X_mean.csv', index = False, header=True)
X_mean
# Out:
#      variable_3  variable_5  variable_6  variable_7  variable_8  variable_10  \
# 0     19.761786   14.635833   22.185582   16.414744   12.615143    15.580604
# 1     19.735279   15.193396   20.831414   15.052533   12.520547    15.145423
# 2     19.116076   15.446714   22.152604   16.410827   12.520547    14.628890
# 3     19.376875   15.460525   22.169389   16.403964   12.720767    15.937169
# 4     19.555938   14.515536   22.150249   16.372219   12.314019    14.950203
# ..          ...         ...         ...         ...         ...          ...
# 181   19.664978   14.447858   20.808503   15.027154   12.648327    14.806952
# 182   19.301954   14.839941   21.085175   15.321075   12.510670    14.488147
# 183   19.170626   14.291711   21.381912   15.197205   12.499558    14.434959
# 184   18.869505   14.440576   20.961485   14.829978   12.312338    14.114074
# 185   18.954904   14.358631   20.005032   15.873984   12.414258    15.138143
#
#      variable_11  variable_14  variable_22  variable_23  ...  variable_2339  \
# 0      15.881437    17.500899    12.792893    16.805604  ...      12.052252
# 1      14.034654    17.953780    12.541715    15.907714  ...      13.020365
# 2      15.316772    17.404715    12.786407    15.947176  ...      12.750163
# 3      15.967749    15.836957    12.541715    16.371211  ...      12.750163
# 4      15.294906    16.610171    12.214057    16.171763  ...      12.750163
# ..           ...          ...          ...          ...  ...            ...
# 181    14.244917    17.126579    12.080710    15.388376  ...      12.349299
# 182    15.163197    16.816591    12.452644    16.474456  ...      12.909283
# 183    14.520558    16.315887    12.808417    15.613263  ...      12.846355
# 184    13.776358    16.110117    12.667428    16.021372  ...      12.477753
# 185    15.179461    15.432975    12.047361    15.443640  ...      13.225899
#
#      variable_2340  variable_2350  variable_2353  variable_2364  \
# 0        12.568647      13.192848      13.230752      12.248590
# 1        12.928643      13.697314      12.922436      12.604052
# 2        12.498674      13.112297      13.330175      12.252300
# 3        12.498674      13.086805      13.304171      12.252300
# 4        12.498674      13.112297      13.306722      12.349830
# ..             ...            ...            ...            ...
# 181      11.505004      13.189121      12.922436      12.252300
# 182      12.642143      13.112297      12.922436      12.708850
# 183      13.243400      13.112297      12.922436      12.199647
# 184      11.789382      13.112297      12.922436      11.628154
# 185      12.978890      11.596877      12.922436      12.252300
#
#      variable_2365  variable_2368  variable_2370  variable_2375  variable_2379
# 0        12.114328      14.269258      12.355017      13.114289      13.882526
# 1        12.083249      13.528211      12.208084      12.686433      13.244201
# 2        12.083249      14.215988      12.305932      12.955618      13.778398
# 3        11.605353      14.284148      12.319119      13.058285      13.812829
# 4        11.926237      14.192775      12.305932      13.006556      13.841201
# ..             ...            ...            ...            ...            ...
# 181      12.083249      13.528211      12.305932      12.686433      13.244201
# 182      12.462751      12.175110      12.635066      12.686433      13.244201
# 183      12.083249      13.528211      12.258149      12.686433      13.244201
# 184      12.083249      13.528211      12.305932      12.686433      13.244201
# 185      12.083249      13.528211      12.158923      12.686433      13.244201
#
# [186 rows x 557 columns]

# %%
# A bit better and can be used for the metabolites with very low number of NaN but it also create big bias
# for metabolites with high number of NaN

# %% [markdown]
# ## Median imputation
#
# For each feature, the missing values are imputed by the median value of the non-missing values in that feature.

# %%
X_median = median_imputer(X)
X_median.to_csv(path_peakTable_imputed + 'X_median.csv', index = False, header=True)
X_median
# Out:
#      variable_3  variable_5  variable_6  variable_7  variable_8  variable_10  \
# 0     19.761786   14.635833   22.185582   16.414744   12.615143    15.580604
# 1     19.735279   15.193396   20.831414   15.052533   12.521564    15.145423
# 2     19.116076   15.446714   22.152604   16.410827   12.521564    14.628890
# 3     19.376875   15.460525   22.169389   16.403964   12.720767    15.937169
# 4     19.555938   14.515536   22.150249   16.372219   12.314019    14.950203
# ..          ...         ...         ...         ...         ...          ...
# 181   19.664978   14.447858   20.808503   15.027154   12.648327    14.806952
# 182   19.301954   14.839941   21.085175   15.321075   12.510670    14.488147
# 183   19.170626   14.291711   21.381912   15.197205   12.499558    14.434959
# 184   18.869505   14.440576   20.961485   14.829978   12.312338    14.114074
# 185   18.954904   14.325310   20.005032   15.994947   12.414258    15.159946
#
#      variable_11  variable_14  variable_22  variable_23  ...  variable_2339  \
# 0      15.881437    17.500899    12.792893    16.805604  ...      12.052252
# 1      14.034654    17.953780    12.484599    15.907714  ...      13.020365
# 2      15.316772    17.404715    12.786407    15.947176  ...      12.750711
# 3      15.967749    15.836957    12.484599    16.371211  ...      12.750711
# 4      15.294906    16.610171    12.214057    16.171763  ...      12.750711
# ..           ...          ...          ...          ...  ...            ...
# 181    14.244917    17.126579    12.080710    15.388376  ...      12.349299
# 182    15.163197    16.816591    12.452644    16.474456  ...      12.909283
# 183    14.520558    16.315887    12.808417    15.613263  ...      12.846355
# 184    13.776358    16.110117    12.667428    16.021372  ...      12.477753
# 185    15.287987    15.432975    12.047361    15.443640  ...      13.225899
#
#      variable_2340  variable_2350  variable_2353  variable_2364  \
# 0        12.568647      13.192848      13.230752      12.248590
# 1        12.928643      13.697314      13.040466      12.604052
# 2        12.522206      13.132347      13.330175      12.272194
# 3        12.522206      13.086805      13.304171      12.272194
# 4        12.522206      13.132347      13.306722      12.349830
# ..             ...            ...            ...            ...
# 181      11.505004      13.189121      13.040466      12.272194
# 182      12.642143      13.132347      13.040466      12.708850
# 183      13.243400      13.132347      13.040466      12.199647
# 184      11.789382      13.132347      13.040466      11.628154
# 185      12.978890      11.596877      13.040466      12.272194
#
#      variable_2365  variable_2368  variable_2370  variable_2375  variable_2379
# 0        12.114328      14.269258      12.355017      13.114289      13.882526
# 1        12.099145      13.766460      12.208084      12.802284      13.413644
# 2        12.099145      14.215988      12.336066      12.955618      13.778398
# 3        11.605353      14.284148      12.319119      13.058285      13.812829
# 4        11.926237      14.192775      12.336066      13.006556      13.841201
# ..             ...            ...            ...            ...            ...
# 181      12.099145      13.766460      12.336066      12.802284      13.413644
# 182      12.462751      12.175110      12.635066      12.802284      13.413644
# 183      12.099145      13.766460      12.258149      12.802284      13.413644
# 184      12.099145      13.766460      12.336066      12.802284      13.413644
# 185      12.099145      13.766460      12.158923      12.802284      13.413644
#
# [186 rows x 557 columns]

# %%
# Quite similar to the mean imputation

# %% [markdown]
# ## Mode imputation (most frequent)
#
# For each feature, the missing values are imputed by the most frequent value (rounded at 1.e-2) of the non-missing values in that feature.

# %%
X_most = mode_imputer(X)
X_most.to_csv(path_peakTable_imputed + 'X_most.csv', index = False, header=True)
X_most
# Out:
#      variable_3  variable_5  variable_6  variable_7  variable_8  variable_10  \
# 0     19.761786   14.635833   22.185582   16.414744   12.615143    15.580604
# 1     19.735279   15.193396   20.831414   15.052533   12.310000    15.145423
# 2     19.116076   15.446714   22.152604   16.410827   12.310000    14.628890
# 3     19.376875   15.460525   22.169389   16.403964   12.720767    15.937169
# 4     19.555938   14.515536   22.150249   16.372219   12.314019    14.950203
# ..          ...         ...         ...         ...         ...          ...
# 181   19.664978   14.447858   20.808503   15.027154   12.648327    14.806952
# 182   19.301954   14.839941   21.085175   15.321075   12.510670    14.488147
# 183   19.170626   14.291711   21.381912   15.197205   12.499558    14.434959
# 184   18.869505   14.440576   20.961485   14.829978   12.312338    14.114074
# 185   18.954904   14.030000   20.005032   16.200000   12.414258    15.290000
#
#      variable_11  variable_14  variable_22  variable_23  ...  variable_2339  \
# 0      15.881437    17.500899    12.792893    16.805604  ...      12.052252
# 1      14.034654    17.953780    11.890000    15.907714  ...      13.020365
# 2      15.316772    17.404715    12.786407    15.947176  ...      12.570000
# 3      15.967749    15.836957    11.890000    16.371211  ...      12.570000
# 4      15.294906    16.610171    12.214057    16.171763  ...      12.570000
# ..           ...          ...          ...          ...  ...            ...
# 181    14.244917    17.126579    12.080710    15.388376  ...      12.349299
# 182    15.163197    16.816591    12.452644    16.474456  ...      12.909283
# 183    14.520558    16.315887    12.808417    15.613263  ...      12.846355
# 184    13.776358    16.110117    12.667428    16.021372  ...      12.477753
# 185    15.140000    15.432975    12.047361    15.443640  ...      13.225899
#
#      variable_2340  variable_2350  variable_2353  variable_2364  \
# 0        12.568647      13.192848      13.230752      12.248590
# 1        12.928643      13.697314      13.100000      12.604052
# 2        12.610000      13.450000      13.330175      12.090000
# 3        12.610000      13.086805      13.304171      12.090000
# 4        12.610000      13.450000      13.306722      12.349830
# ..             ...            ...            ...            ...
# 181      11.505004      13.189121      13.100000      12.090000
# 182      12.642143      13.450000      13.100000      12.708850
# 183      13.243400      13.450000      13.100000      12.199647
# 184      11.789382      13.450000      13.100000      11.628154
# 185      12.978890      11.596877      13.100000      12.090000
#
#      variable_2365  variable_2368  variable_2370  variable_2375  variable_2379
# 0        12.114328      14.269258      12.355017      13.114289      13.882526
# 1        12.110000      13.860000      12.208084      13.050000      13.800000
# 2        12.110000      14.215988      12.130000      12.955618      13.778398
# 3        11.605353      14.284148      12.319119      13.058285      13.812829
# 4        11.926237      14.192775      12.130000      13.006556      13.841201
# ..             ...            ...            ...            ...            ...
# 181      12.110000      13.860000      12.130000      13.050000      13.800000
# 182      12.462751      12.175110      12.635066      13.050000      13.800000
# 183      12.110000      13.860000      12.258149      13.050000      13.800000
# 184      12.110000      13.860000      12.130000      13.050000      13.800000
# 185      12.110000      13.860000      12.158923      13.050000      13.800000
#
# [186 rows x 557 columns]

# %%
# Takes the most frequent value per metabolite and give it to the NaN.

# %% [markdown]
# ## Imputation with minimum value of the feature
#
# For each feature, the missing values are imputed by the minimum value of the non-missing values in that feature.

# %%
X_min_f = min_imputer(X)
X_min_f.to_csv(path_peakTable_imputed + 'X_min_f.csv', index = False, header=True)
X_min_f
# Out:
#      variable_3  variable_5  variable_6  variable_7  variable_8  variable_10  \
# 0     19.761786   14.635833   22.185582   16.414744   12.615143    15.580604
# 1     19.735279   15.193396   20.831414   15.052533   11.938442    15.145423
# 2     19.116076   15.446714   22.152604   16.410827   11.938442    14.628890
# 3     19.376875   15.460525   22.169389   16.403964   12.720767    15.937169
# 4     19.555938   14.515536   22.150249   16.372219   12.314019    14.950203
# ..          ...         ...         ...         ...         ...          ...
# 181   19.664978   14.447858   20.808503   15.027154   12.648327    14.806952
# 182   19.301954   14.839941   21.085175   15.321075   12.510670    14.488147
# 183   19.170626   14.291711   21.381912   15.197205   12.499558    14.434959
# 184   18.869505   14.440576   20.961485   14.829978   12.312338    14.114074
# 185   18.954904   13.331213   20.005032   14.498838   12.414258    12.051625
#
#      variable_11  variable_14  variable_22  variable_23  ...  variable_2339  \
# 0      15.881437    17.500899    12.792893    16.805604  ...      12.052252
# 1      14.034654    17.953780    11.790797    15.907714  ...      13.020365
# 2      15.316772    17.404715    12.786407    15.947176  ...      11.716583
# 3      15.967749    15.836957    11.790797    16.371211  ...      11.716583
# 4      15.294906    16.610171    12.214057    16.171763  ...      11.716583
# ..           ...          ...          ...          ...  ...            ...
# 181    14.244917    17.126579    12.080710    15.388376  ...      12.349299
# 182    15.163197    16.816591    12.452644    16.474456  ...      12.909283
# 183    14.520558    16.315887    12.808417    15.613263  ...      12.846355
# 184    13.776358    16.110117    12.667428    16.021372  ...      12.477753
# 185    12.273922    15.432975    12.047361    15.443640  ...      13.225899
#
#      variable_2340  variable_2350  variable_2353  variable_2364  \
# 0        12.568647      13.192848      13.230752      12.248590
# 1        12.928643      13.697314      11.694949      12.604052
# 2        11.505004      11.596877      13.330175      11.534573
# 3        11.505004      13.086805      13.304171      11.534573
# 4        11.505004      11.596877      13.306722      12.349830
# ..             ...            ...            ...            ...
# 181      11.505004      13.189121      11.694949      11.534573
# 182      12.642143      11.596877      11.694949      12.708850
# 183      13.243400      11.596877      11.694949      12.199647
# 184      11.789382      11.596877      11.694949      11.628154
# 185      12.978890      11.596877      11.694949      11.534573
#
#      variable_2365  variable_2368  variable_2370  variable_2375  variable_2379
# 0        12.114328      14.269258      12.355017      13.114289      13.882526
# 1        11.586262      11.943859      12.208084      11.620127      11.742119
# 2        11.586262      14.215988      11.640240      12.955618      13.778398
# 3        11.605353      14.284148      12.319119      13.058285      13.812829
# 4        11.926237      14.192775      11.640240      13.006556      13.841201
# ..             ...            ...            ...            ...            ...
# 181      11.586262      11.943859      11.640240      11.620127      11.742119
# 182      12.462751      12.175110      12.635066      11.620127      11.742119
# 183      11.586262      11.943859      12.258149      11.620127      11.742119
# 184      11.586262      11.943859      11.640240      11.620127      11.742119
# 185      11.586262      11.943859      12.158923      11.620127      11.742119
#
# [186 rows x 557 columns]

# %%
# Gives the min value to NaN so it creates a bias on low value

# %% [markdown]
# ### imputation with half minimum value of the feature
#
# For each feature, the missing values are imputed by the half of the minimum value of the non-missing values in that feature.

# %%
X_half_min_f = half_min_imputer(X)
X_half_min_f.to_csv(path_peakTable_imputed + 'X_half_min_f.csv', index = False, header=True)
X_half_min_f
# Out:
#      variable_3  variable_5  variable_6  variable_7  variable_8  variable_10  \
# 0     19.761786   14.635833   22.185582   16.414744   12.615143    15.580604
# 1     19.735279   15.193396   20.831414   15.052533    5.969221    15.145423
# 2     19.116076   15.446714   22.152604   16.410827    5.969221    14.628890
# 3     19.376875   15.460525   22.169389   16.403964   12.720767    15.937169
# 4     19.555938   14.515536   22.150249   16.372219   12.314019    14.950203
# ..          ...         ...         ...         ...         ...          ...
# 181   19.664978   14.447858   20.808503   15.027154   12.648327    14.806952
# 182   19.301954   14.839941   21.085175   15.321075   12.510670    14.488147
# 183   19.170626   14.291711   21.381912   15.197205   12.499558    14.434959
# 184   18.869505   14.440576   20.961485   14.829978   12.312338    14.114074
# 185   18.954904    6.665606   20.005032    7.249419   12.414258     6.025813
#
#      variable_11  variable_14  variable_22  variable_23  ...  variable_2339  \
# 0      15.881437    17.500899    12.792893    16.805604  ...      12.052252
# 1      14.034654    17.953780     5.895398    15.907714  ...      13.020365
# 2      15.316772    17.404715    12.786407    15.947176  ...       5.858291
# 3      15.967749    15.836957     5.895398    16.371211  ...       5.858291
# 4      15.294906    16.610171    12.214057    16.171763  ...       5.858291
# ..           ...          ...          ...          ...  ...            ...
# 181    14.244917    17.126579    12.080710    15.388376  ...      12.349299
# 182    15.163197    16.816591    12.452644    16.474456  ...      12.909283
# 183    14.520558    16.315887    12.808417    15.613263  ...      12.846355
# 184    13.776358    16.110117    12.667428    16.021372  ...      12.477753
# 185     6.136961    15.432975    12.047361    15.443640  ...      13.225899
#
#      variable_2340  variable_2350  variable_2353  variable_2364  \
# 0        12.568647      13.192848      13.230752      12.248590
# 1        12.928643      13.697314       5.847475      12.604052
# 2         5.752502       5.798439      13.330175       5.767286
# 3         5.752502      13.086805      13.304171       5.767286
# 4         5.752502       5.798439      13.306722      12.349830
# ..             ...            ...            ...            ...
# 181      11.505004      13.189121       5.847475       5.767286
# 182      12.642143       5.798439       5.847475      12.708850
# 183      13.243400       5.798439       5.847475      12.199647
# 184      11.789382       5.798439       5.847475      11.628154
# 185      12.978890      11.596877       5.847475       5.767286
#
#      variable_2365  variable_2368  variable_2370  variable_2375  variable_2379
# 0        12.114328      14.269258      12.355017      13.114289      13.882526
# 1         5.793131       5.971930      12.208084       5.810064       5.871059
# 2         5.793131      14.215988       5.820120      12.955618      13.778398
# 3        11.605353      14.284148      12.319119      13.058285      13.812829
# 4        11.926237      14.192775       5.820120      13.006556      13.841201
# ..             ...            ...            ...            ...            ...
# 181       5.793131       5.971930       5.820120       5.810064       5.871059
# 182      12.462751      12.175110      12.635066       5.810064       5.871059
# 183       5.793131       5.971930      12.258149       5.810064       5.871059
# 184       5.793131       5.971930       5.820120       5.810064       5.871059
# 185       5.793131       5.971930      12.158923       5.810064       5.871059
#
# [186 rows x 557 columns]

# %%
# Gives the min value to NaN so it creates an even bigger bias on low value

# %%
#X_max_f = max_imputer(X)
#X_max_f.to_csv(path_peakTable_imputed + 'X_max_f.csv', index = False, header=True)
#X_max_f

# No implemented

# %% [markdown]
# # Multivariate feature imputation
#
# [cf. doc scikitlearn IterativeImputer](https://scikit-learn.org/stable/modules/generated/sklearn.impute.IterativeImputer.html#sklearn.impute.IterativeImputer)
#
# <code>IterativeImputer</code> was inspired by the R MICE package (Multivariate Imputation by Chained Equations).
#
# On this page ([link](https://scikit-learn.org/stable/auto_examples/impute/plot_iterative_imputer_variants_comparison.html)) are presented the different possible estimators that can be applied with <code>IterativeImputer</code> :
# - <code>BayesianRidge</code> : regularized linear regression
# - <code>DecisionTreeRegressor</code> : non-linear regression
# - <code>ExtraTreesRegressor</code> : similar to missForest in R
# - <code>KNeighborsRegressor</code> : comparable to other KNN imputation approaches

# %%
from sklearn.linear_model import BayesianRidge
from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import ExtraTreesRegressor
from sklearn.neighbors import KNeighborsRegressor

# %%
estimators = [
    BayesianRidge(),
    DecisionTreeRegressor(max_features='sqrt', random_state=0),
    ExtraTreesRegressor(n_estimators=10, random_state=0),
    KNeighborsRegressor(n_neighbors=15)
]

# %%
for estimator in estimators:
    
    X_python_MICE = python_MICE_imputer(X, estimator)
    
    X_python_MICE.to_csv(path_peakTable_imputed + 'X_python_MICE_' + str(estimator).split('(')[0] + '.csv', index = False, header=True)
# Out:
# /opt/anaconda3/lib/python3.7/site-packages/sklearn/impute/_iterative.py:701: ConvergenceWarning: [IterativeImputer] Early stopping criterion not reached.
#   ConvergenceWarning,
# ----- 8.8 seconds -----
# /opt/anaconda3/lib/python3.7/site-packages/sklearn/impute/_iterative.py:701: ConvergenceWarning: [IterativeImputer] Early stopping criterion not reached.
#   ConvergenceWarning,
# ----- 6.2 seconds -----
# /opt/anaconda3/lib/python3.7/site-packages/sklearn/impute/_iterative.py:701: ConvergenceWarning: [IterativeImputer] Early stopping criterion not reached.
#   ConvergenceWarning,
# ----- 54.3 seconds -----
# /opt/anaconda3/lib/python3.7/site-packages/sklearn/impute/_iterative.py:701: ConvergenceWarning: [IterativeImputer] Early stopping criterion not reached.
#   ConvergenceWarning,
# ----- 7.1 seconds -----

# %%
Bayesian = pd.read_csv(path_peakTable_imputed+'X_python_MICE_BayesianRidge.csv')
Decision_tree = pd.read_csv(path_peakTable_imputed+'X_python_MICE_DecisionTreeRegressor.csv')
Extra_tree = pd.read_csv(path_peakTable_imputed+'X_python_MICE_ExtraTreesRegressor.csv')
K_neighbors = pd.read_csv(path_peakTable_imputed+'X_python_MICE_KNeighborsRegressor.csv')

# %%
Bayesian
# Out:
#      variable_3  variable_5  variable_6  variable_7  variable_8  variable_10  \
# 0     19.761786   14.635833   22.185582   16.414744   12.615143    15.580604
# 1     19.735279   15.193396   20.831414   15.052533   12.459782    15.145423
# 2     19.116076   15.446714   22.152604   16.410827   12.492690    14.628890
# 3     19.376875   15.460525   22.169389   16.403964   12.720767    15.937169
# 4     19.555938   14.515536   22.150249   16.372219   12.314019    14.950203
# ..          ...         ...         ...         ...         ...          ...
# 181   19.664978   14.447858   20.808503   15.027154   12.648327    14.806952
# 182   19.301954   14.839941   21.085175   15.321075   12.510670    14.488147
# 183   19.170626   14.291711   21.381912   15.197205   12.499558    14.434959
# 184   18.869505   14.440576   20.961485   14.829978   12.312338    14.114074
# 185   18.954904   13.886383   20.005032   14.065988   12.414258    11.292689
#
#      variable_11  variable_14  variable_22  variable_23  ...  variable_2339  \
# 0      15.881437    17.500899    12.792893    16.805604  ...      12.052252
# 1      14.034654    17.953780    11.659719    15.907714  ...      13.020365
# 2      15.316772    17.404715    12.786407    15.947176  ...      12.797947
# 3      15.967749    15.836957    11.756784    16.371211  ...      12.783034
# 4      15.294906    16.610171    12.214057    16.171763  ...      12.707177
# ..           ...          ...          ...          ...  ...            ...
# 181    14.244917    17.126579    12.080710    15.388376  ...      12.349299
# 182    15.163197    16.816591    12.452644    16.474456  ...      12.909283
# 183    14.520558    16.315887    12.808417    15.613263  ...      12.846355
# 184    13.776358    16.110117    12.667428    16.021372  ...      12.477753
# 185    12.964763    15.432975    12.047361    15.443640  ...      13.225899
#
#      variable_2340  variable_2350  variable_2353  variable_2364  \
# 0        12.568647      13.192848      13.230752      12.248590
# 1        12.928643      13.697314      10.424025      12.604052
# 2        12.311173      11.704682      13.330175      12.149410
# 3        12.378222      13.086805      13.304171      12.228991
# 4        12.358299      12.199886      13.306722      12.349830
# ..             ...            ...            ...            ...
# 181      11.505004      13.189121      10.625342      12.220451
# 182      12.642143      12.055818      11.430290      12.708850
# 183      13.243400      12.421730      11.153673      12.199647
# 184      11.789382      11.964976       9.983221      11.628154
# 185      12.978890      11.596877       8.621061      12.160254
#
#      variable_2365  variable_2368  variable_2370  variable_2375  variable_2379
# 0        12.114328      14.269258      12.355017      13.114289      13.882526
# 1        12.090394      10.900672      12.208084      10.568388      11.330137
# 2        12.085384      14.215988      12.300756      12.955618      13.778398
# 3        11.605353      14.284148      12.319119      13.058285      13.812829
# 4        11.926237      14.192775      12.286558      13.006556      13.841201
# ..             ...            ...            ...            ...            ...
# 181      12.110192      11.363959      12.349143      10.479248      11.616014
# 182      12.462751      12.175110      12.635066      11.290728      12.202157
# 183      12.103923      11.753963      12.258149      10.913551      11.816932
# 184      12.091796      10.365432      12.332963       9.976281      11.204208
# 185      12.125050       9.395136      12.158923       8.966766       9.561203
#
# [186 rows x 557 columns]

# %%
Decision_tree
# Out:
#      variable_3  variable_5  variable_6  variable_7  variable_8  variable_10  \
# 0     19.761786   14.635833   22.185582   16.414744   12.615143    15.580604
# 1     19.735279   15.193396   20.831414   15.052533   12.186561    15.145423
# 2     19.116076   15.446714   22.152604   16.410827   12.698220    14.628890
# 3     19.376875   15.460525   22.169389   16.403964   12.720767    15.937169
# 4     19.555938   14.515536   22.150249   16.372219   12.314019    14.950203
# ..          ...         ...         ...         ...         ...          ...
# 181   19.664978   14.447858   20.808503   15.027154   12.648327    14.806952
# 182   19.301954   14.839941   21.085175   15.321075   12.510670    14.488147
# 183   19.170626   14.291711   21.381912   15.197205   12.499558    14.434959
# 184   18.869505   14.440576   20.961485   14.829978   12.312338    14.114074
# 185   18.954904   14.440576   20.005032   15.157521   12.414258    12.293375
#
#      variable_11  variable_14  variable_22  variable_23  ...  variable_2339  \
# 0      15.881437    17.500899    12.792893    16.805604  ...      12.052252
# 1      14.034654    17.953780    12.214057    15.907714  ...      13.020365
# 2      15.316772    17.404715    12.786407    15.947176  ...      11.716583
# 3      15.967749    15.836957    12.387287    16.371211  ...      11.716583
# 4      15.294906    16.610171    12.214057    16.171763  ...      12.420496
# ..           ...          ...          ...          ...  ...            ...
# 181    14.244917    17.126579    12.080710    15.388376  ...      12.349299
# 182    15.163197    16.816591    12.452644    16.474456  ...      12.909283
# 183    14.520558    16.315887    12.808417    15.613263  ...      12.846355
# 184    13.776358    16.110117    12.667428    16.021372  ...      12.477753
# 185    12.995771    15.432975    12.047361    15.443640  ...      13.225899
#
#      variable_2340  variable_2350  variable_2353  variable_2364  \
# 0        12.568647      13.192848      13.230752      12.248590
# 1        12.928643      13.697314      11.710278      12.604052
# 2        12.175405      12.639742      13.330175      12.292704
# 3        12.928643      13.086805      13.304171      12.015647
# 4        12.485271      12.443033      13.306722      12.349830
# ..             ...            ...            ...            ...
# 181      11.505004      13.189121      11.710278      12.285457
# 182      12.642143      12.737873      11.710278      12.708850
# 183      13.243400      12.998651      11.710278      12.199647
# 184      11.789382      12.487315      11.710278      11.628154
# 185      12.978890      11.596877      12.114855      11.674663
#
#      variable_2365  variable_2368  variable_2370  variable_2375  variable_2379
# 0        12.114328      14.269258      12.355017      13.114289      13.882526
# 1        12.092734      13.378094      12.208084      11.878035      11.913031
# 2        11.926237      14.215988      12.149785      12.955618      13.778398
# 3        11.605353      14.284148      12.319119      13.058285      13.812829
# 4        11.926237      14.192775      11.958665      13.006556      13.841201
# ..             ...            ...            ...            ...            ...
# 181      12.215795      12.175110      11.712856      11.878035      11.742119
# 182      12.462751      12.175110      12.635066      11.641326      11.935622
# 183      11.993660      12.175110      12.258149      11.641326      11.759320
# 184      12.069877      13.179959      12.210678      11.869920      11.800952
# 185      12.069877      11.943859      12.158923      11.878035      11.987260
#
# [186 rows x 557 columns]

# %%
Extra_tree
# Out:
#      variable_3  variable_5  variable_6  variable_7  variable_8  variable_10  \
# 0     19.761786   14.635833   22.185582   16.414744   12.615143    15.580604
# 1     19.735279   15.193396   20.831414   15.052533   12.443818    15.145423
# 2     19.116076   15.446714   22.152604   16.410827   12.453086    14.628890
# 3     19.376875   15.460525   22.169389   16.403964   12.720767    15.937169
# 4     19.555938   14.515536   22.150249   16.372219   12.314019    14.950203
# ..          ...         ...         ...         ...         ...          ...
# 181   19.664978   14.447858   20.808503   15.027154   12.648327    14.806952
# 182   19.301954   14.839941   21.085175   15.321075   12.510670    14.488147
# 183   19.170626   14.291711   21.381912   15.197205   12.499558    14.434959
# 184   18.869505   14.440576   20.961485   14.829978   12.312338    14.114074
# 185   18.954904   13.681039   20.005032   14.642579   12.414258    12.566592
#
#      variable_11  variable_14  variable_22  variable_23  ...  variable_2339  \
# 0      15.881437    17.500899    12.792893    16.805604  ...      12.052252
# 1      14.034654    17.953780    11.966551    15.907714  ...      13.020365
# 2      15.316772    17.404715    12.786407    15.947176  ...      13.001330
# 3      15.967749    15.836957    12.110416    16.371211  ...      12.640942
# 4      15.294906    16.610171    12.214057    16.171763  ...      12.465851
# ..           ...          ...          ...          ...  ...            ...
# 181    14.244917    17.126579    12.080710    15.388376  ...      12.349299
# 182    15.163197    16.816591    12.452644    16.474456  ...      12.909283
# 183    14.520558    16.315887    12.808417    15.613263  ...      12.846355
# 184    13.776358    16.110117    12.667428    16.021372  ...      12.477753
# 185    12.888375    15.432975    12.047361    15.443640  ...      13.225899
#
#      variable_2340  variable_2350  variable_2353  variable_2364  \
# 0        12.568647      13.192848      13.230752      12.248590
# 1        12.928643      13.697314      11.710278      12.604052
# 2        12.203972      12.181535      13.330175      12.014642
# 3        12.439991      13.086805      13.304171      12.219473
# 4        12.285877      12.223589      13.306722      12.349830
# ..             ...            ...            ...            ...
# 181      11.505004      13.189121      11.831226      12.081714
# 182      12.642143      12.157820      11.894774      12.708850
# 183      13.243400      12.452831      11.862687      12.199647
# 184      11.789382      12.099319      11.897465      11.628154
# 185      12.978890      11.596877      12.005679      12.082779
#
#      variable_2365  variable_2368  variable_2370  variable_2375  variable_2379
# 0        12.114328      14.269258      12.355017      13.114289      13.882526
# 1        12.195931      12.245397      12.208084      11.837663      11.901965
# 2        11.978295      14.215988      12.115786      12.955618      13.778398
# 3        11.605353      14.284148      12.319119      13.058285      13.812829
# 4        11.926237      14.192775      12.184269      13.006556      13.841201
# ..             ...            ...            ...            ...            ...
# 181      11.962661      12.049694      12.273025      11.750050      11.787904
# 182      12.462751      12.175110      12.635066      11.665590      12.069786
# 183      11.932017      12.112848      12.258149      11.656638      11.914409
# 184      11.946076      12.059944      12.169376      11.671950      11.796230
# 185      12.047847      12.157779      12.158923      11.736584      11.826069
#
# [186 rows x 557 columns]

# %%
K_neighbors
# Out:
#      variable_3  variable_5  variable_6  variable_7  variable_8  variable_10  \
# 0     19.761786   14.635833   22.185582   16.414744   12.615143    15.580604
# 1     19.735279   15.193396   20.831414   15.052533   12.391614    15.145423
# 2     19.116076   15.446714   22.152604   16.410827   12.475976    14.628890
# 3     19.376875   15.460525   22.169389   16.403964   12.720767    15.937169
# 4     19.555938   14.515536   22.150249   16.372219   12.314019    14.950203
# ..          ...         ...         ...         ...         ...          ...
# 181   19.664978   14.447858   20.808503   15.027154   12.648327    14.806952
# 182   19.301954   14.839941   21.085175   15.321075   12.510670    14.488147
# 183   19.170626   14.291711   21.381912   15.197205   12.499558    14.434959
# 184   18.869505   14.440576   20.961485   14.829978   12.312338    14.114074
# 185   18.954904   13.986335   20.005032   15.027509   12.414258    13.952816
#
#      variable_11  variable_14  variable_22  variable_23  ...  variable_2339  \
# 0      15.881437    17.500899    12.792893    16.805604  ...      12.052252
# 1      14.034654    17.953780    12.492231    15.907714  ...      13.020365
# 2      15.316772    17.404715    12.786407    15.947176  ...      12.997888
# 3      15.967749    15.836957    12.387244    16.371211  ...      12.732983
# 4      15.294906    16.610171    12.214057    16.171763  ...      12.774959
# ..           ...          ...          ...          ...  ...            ...
# 181    14.244917    17.126579    12.080710    15.388376  ...      12.349299
# 182    15.163197    16.816591    12.452644    16.474456  ...      12.909283
# 183    14.520558    16.315887    12.808417    15.613263  ...      12.846355
# 184    13.776358    16.110117    12.667428    16.021372  ...      12.477753
# 185    14.071615    15.432975    12.047361    15.443640  ...      13.225899
#
#      variable_2340  variable_2350  variable_2353  variable_2364  \
# 0        12.568647      13.192848      13.230752      12.248590
# 1        12.928643      13.697314      12.333575      12.604052
# 2        12.467490      12.536132      13.330175      12.221190
# 3        12.527512      13.086805      13.304171      12.173609
# 4        12.543966      12.473793      13.306722      12.349830
# ..             ...            ...            ...            ...
# 181      11.505004      13.189121      12.087981      12.120934
# 182      12.642143      12.577848      12.514789      12.708850
# 183      13.243400      12.503732      12.329759      12.199647
# 184      11.789382      12.332603      12.126727      11.628154
# 185      12.978890      11.596877      12.508860      12.238229
#
#      variable_2365  variable_2368  variable_2370  variable_2375  variable_2379
# 0        12.114328      14.269258      12.355017      13.114289      13.882526
# 1        12.078319      12.732674      12.208084      12.668262      13.708118
# 2        12.093288      14.215988      12.361386      12.955618      13.778398
# 3        11.605353      14.284148      12.319119      13.058285      13.812829
# 4        11.926237      14.192775      12.310450      13.006556      13.841201
# ..             ...            ...            ...            ...            ...
# 181      12.177854      12.425695      12.387938      12.228839      12.645422
# 182      12.462751      12.175110      12.635066      12.090925      12.667477
# 183      12.129380      12.425391      12.258149      12.190081      12.766714
# 184      12.090942      12.417552      12.430206      12.137077      12.758119
# 185      12.107967      12.467366      12.158923      12.172439      12.659892
#
# [186 rows x 557 columns]

# %% [markdown]
# ## Nearest neighbors imputation
#
# According to scikit-learn documentation (https://scikit-learn.org/stable/modules/impute.html#nearest-neighbors-imputation), "Each missing feature is imputed using values from n_neighbors nearest neighbors that have a value for the feature. The feature of the neighbors are averaged uniformly or weighted by distance to each neighbor. If a sample has more than one feature missing, then the neighbors for that sample can be different depending on the particular feature being imputed."
#
# We let the possibility for the user to impute the values along the two axis with the parameter 'by' :
# - by='samples' (default) : the missing value for a specific feature in a sample is imputed using the values of that feature in the n_neighbors samples which have a non-missing value for that feature
# - by='feature' : the missing value for a specific feature in a sample is imputed using the values of the n_neighbors features in that sample which have a non-missing value for that sample

# %%
X_KNN_features = KNN_imputer(X, by='features')
X_KNN_features.columns = X.columns
X_KNN_features.to_csv(path_peakTable_imputed + 'X_KNN_features.csv', index=False, header=True)
X_KNN_features.head(15)
# Out:
#     variable_3  variable_5  variable_6  variable_7  variable_8  variable_10  \
# 0    19.761786   14.635833   22.185582   16.414744   12.615143    15.580604
# 1    19.735279   15.193396   20.831414   15.052533   12.537659    15.145423
# 2    19.116076   15.446714   22.152604   16.410827   12.440713    14.628890
# 3    19.376875   15.460525   22.169389   16.403964   12.720767    15.937169
# 4    19.555938   14.515536   22.150249   16.372219   12.314019    14.950203
# 5    19.377437   14.913215   22.198844   16.428678   12.505492    14.850260
# 6    19.526568   14.648653   22.092599   16.311085   12.472396    14.927456
# 7    19.349326   14.454301   22.093306   16.302336   12.563764    14.696175
# 8    19.610237   14.713504   22.006737   16.196649   12.438756    14.229462
# 9    19.409257   14.916472   22.122923   16.322582   12.698220    14.995319
# 10   19.458986   14.715541   22.188102   16.412098   12.680790    15.438841
# 11   19.417123   14.546802   22.152231   16.360201   12.523461    14.765801
# 12   19.456756   14.569469   22.126302   16.301957   12.399680    15.159946
# 13   19.793048   14.737229   22.201186   16.404767   12.802906    15.293087
# 14   19.452272   15.067445   21.795735   16.079068   12.696082    15.450530
#
#     variable_11  variable_14  variable_22  variable_23  ...  variable_2339  \
# 0     15.881437    17.500899    12.792893    16.805604  ...      12.052252
# 1     14.034654    17.953780    12.654495    15.907714  ...      13.020365
# 2     15.316772    17.404715    12.786407    15.947176  ...      12.577257
# 3     15.967749    15.836957    12.545616    16.371211  ...      12.704279
# 4     15.294906    16.610171    12.214057    16.171763  ...      12.691802
# 5     15.221202    15.810536    13.419177    15.894322  ...      12.821869
# 6     15.384976    14.851520    12.568060    15.957313  ...      12.551415
# 7     15.070685    17.525085    12.488024    16.059188  ...      12.740471
# 8     15.168583    20.199479    12.635056    15.528091  ...      12.653880
# 9     15.113511    15.889986    12.660146    15.518852  ...      12.053509
# 10    15.744658    20.854291    12.926100    16.022061  ...      12.464260
# 11    15.347317    15.965985    12.524522    15.718685  ...      11.716583
# 12    14.863913    16.770505    11.973431    15.865381  ...      12.332841
# 13    15.634570    17.037027    12.494915    16.297966  ...      12.593859
# 14    15.437327    16.641808    12.496447    15.897319  ...      13.606699
#
#     variable_2340  variable_2350  variable_2353  variable_2364  variable_2365  \
# 0       12.568647      13.192848      13.230752      12.248590      12.114328
# 1       12.928643      13.697314      12.967661      12.604052      12.203777
# 2       12.292346      13.189135      13.330175      12.127478      11.975524
# 3       12.443420      13.086805      13.304171      12.178640      11.605353
# 4       12.322645      13.224206      13.306722      12.349830      11.926237
# 5       12.383368      13.277552      13.468376      12.553141      12.124215
# 6       12.590466      12.046802      13.257812      12.057249      11.967111
# 7       12.551010      12.982756      13.167145      12.423250      11.645077
# 8       12.357255      13.772616      13.126853      12.559007      12.043042
# 9       12.441684      13.580326      13.283324      12.166298      12.081167
# 10      12.766416      12.060652      13.446875      11.996045      12.320520
# 11      12.475476      13.941537      13.301791      11.718316      11.610224
# 12      12.274533      13.024862      13.300254      12.144764      12.128360
# 13      12.635746      13.127468      13.356136      12.425704      12.005378
# 14      12.903134      12.337137      12.911013      12.641051      12.226943
#
#     variable_2368  variable_2370  variable_2375  variable_2379
# 0       14.269258      12.355017      13.114289      13.882526
# 1       13.334666      12.208084      13.070165      12.876716
# 2       14.215988      12.165767      12.955618      13.778398
# 3       14.284148      12.319119      13.058285      13.812829
# 4       14.192775      12.140768      13.006556      13.841201
# 5       14.353224      12.255451      13.006797      13.968235
# 6       14.068035      12.122220      13.015433      13.797054
# 7       14.090122      12.192460      12.939756      13.582338
# 8       14.176808      11.652428      12.983154      13.672213
# 9       14.172761      12.269479      12.929704      13.798821
# 10      14.368564      12.047480      13.304674      13.979732
# 11      14.141841      12.125406      13.053946      13.874695
# 12      14.163230      12.413431      12.949132      13.844655
# 13      14.264617      12.566449      13.062456      13.974848
# 14      13.787496      12.279991      12.479307      13.272192
#
# [15 rows x 557 columns]

# %%
X_KNN_samples = KNN_imputer(X, by='samples')
X_KNN_samples.columns = X.columns
X_KNN_samples.to_csv(path_peakTable_imputed + 'X_KNN_samples.csv', index=False, header=True)
X_KNN_samples.head(15)
# Out:
#     variable_3  variable_5  variable_6  variable_7  variable_8  variable_10  \
# 0    19.761786   14.635833   22.185582   16.414744   12.615143    15.580604
# 1    19.735279   15.193396   20.831414   15.052533   12.519222    15.145423
# 2    19.116076   15.446714   22.152604   16.410827   12.383736    14.628890
# 3    19.376875   15.460525   22.169389   16.403964   12.720767    15.937169
# 4    19.555938   14.515536   22.150249   16.372219   12.314019    14.950203
# 5    19.377437   14.913215   22.198844   16.428678   12.440807    14.850260
# 6    19.526568   14.648653   22.092599   16.311085   12.472396    14.927456
# 7    19.349326   14.454301   22.093306   16.302336   12.425016    14.696175
# 8    19.610237   14.713504   22.006737   16.196649   12.438756    14.229462
# 9    19.409257   14.916472   22.122923   16.322582   12.698220    14.995319
# 10   19.458986   14.715541   22.188102   16.412098   12.680790    15.438841
# 11   19.417123   14.546802   22.152231   16.360201   12.563027    14.765801
# 12   19.456756   14.569469   22.126302   16.301957   12.399680    15.159946
# 13   19.793048   14.737229   22.201186   16.404767   12.802906    15.293087
# 14   19.452272   15.067445   21.795735   16.079068   12.696082    15.450530
#
#     variable_11  variable_14  variable_22  variable_23  ...  variable_2339  \
# 0     15.881437    17.500899    12.792893    16.805604  ...      12.052252
# 1     14.034654    17.953780    11.971249    15.907714  ...      13.020365
# 2     15.316772    17.404715    12.786407    15.947176  ...      12.411317
# 3     15.967749    15.836957    12.278686    16.371211  ...      12.674914
# 4     15.294906    16.610171    12.214057    16.171763  ...      12.731422
# 5     15.221202    15.810536    13.419177    15.894322  ...      12.483089
# 6     15.384976    14.851520    12.394112    15.957313  ...      12.551415
# 7     15.070685    17.525085    12.227243    16.059188  ...      12.442527
# 8     15.168583    20.199479    12.205172    15.528091  ...      12.436157
# 9     15.113511    15.889986    12.307252    15.518852  ...      12.053509
# 10    15.744658    20.854291    12.926100    16.022061  ...      12.464260
# 11    15.347317    15.965985    12.555947    15.718685  ...      11.716583
# 12    14.863913    16.770505    11.973431    15.865381  ...      12.595303
# 13    15.634570    17.037027    12.494915    16.297966  ...      12.470127
# 14    15.437327    16.641808    12.196322    15.897319  ...      13.606699
#
#     variable_2340  variable_2350  variable_2353  variable_2364  variable_2365  \
# 0       12.568647      13.192848      13.230752      12.248590      12.114328
# 1       12.928643      13.697314      12.927804      12.604052      12.102163
# 2       12.379802      13.136575      13.330175      12.226220      11.877304
# 3       12.621035      13.086805      13.304171      12.298832      11.605353
# 4       12.521877      12.617334      13.306722      12.349830      11.926237
# 5       12.522343      13.339494      13.468376      12.553141      12.057998
# 6       12.590466      12.046802      13.257812      12.376686      11.967111
# 7       12.421075      12.579144      13.167145      12.423250      11.645077
# 8       12.536510      13.772616      13.126853      12.559007      11.948858
# 9       12.373973      13.580326      13.283324      11.996065      11.852181
# 10      12.766416      12.060652      13.446875      11.996045      12.320520
# 11      12.331222      13.941537      13.301791      11.718316      11.610224
# 12      12.406386      13.024862      13.300254      12.329091      11.917480
# 13      12.251915      12.992525      13.356136      12.058268      11.880530
# 14      12.903134      12.337137      12.911013      12.641051      12.226943
#
#     variable_2368  variable_2370  variable_2375  variable_2379
# 0       14.269258      12.355017      13.114289      13.882526
# 1       13.568853      12.208084      12.609957      13.452546
# 2       14.215988      12.185576      12.955618      13.778398
# 3       14.284148      12.319119      13.058285      13.812829
# 4       14.192775      12.356960      13.006556      13.841201
# 5       14.353224      12.273192      13.006797      13.968235
# 6       14.068035      12.288752      13.015433      13.797054
# 7       14.090122      12.190740      12.939756      13.582338
# 8       14.176808      11.652428      12.983154      13.672213
# 9       14.172761      12.210828      12.929704      13.798821
# 10      14.368564      12.047480      12.991308      13.979732
# 11      14.141841      12.144713      13.053946      13.874695
# 12      14.163230      12.312375      12.949132      13.844655
# 13      14.264617      12.155306      13.062456      13.974848
# 14      13.787496      12.384764      12.479307      13.272192
#
# [15 rows x 557 columns]

# %%
X_KNN_samples['variable_2364'].mean()
# Out:
# 12.254760267598696

# %%
X_KNN_samples.iloc[6].mean()
# Out:
# 14.934286452625157

# %%
# We tried different things but we don't have any conclusion

# %% [markdown]
# ---
# # Missing value imputation using R MICE package
#
# Here is a link where the [MICE algorithm is explained](https://cran.r-project.org/web/packages/miceRanger/vignettes/miceAlgorithm.html).
#
# The MICE (Multivariate Imputation by Chained Equations) algorithm is a multivariate method to impute missing values. Each missing value is imputed using a separate model with the other variables in the dataset. Iterations should be run until it appears that convergence has been met. The computational time can be huge, thus we proceed in four steps :
# - using the <code>quickpred</code> function ([documentation](https://cran.r-project.org/web/packages/mice/mice.pdf#Rfn.quickpred.1)), we create a squared (column number of the peak table) binary matrix (<code>predictorMatrix</code>), in which $\mathcal{M}_{i,j} = 1$ if we can use the variable $j$ to impute the missing values of the variable $i$, $\mathcal{M}_{i,j} = 0$ otherwise. With this step, only the variables which have a given minimum correlation value can be used to impute the missing values, thus reducing the computational time.
# - using the <code>mice</code> function ([documentation](https://cran.r-project.org/web/packages/mice/mice.pdf#Rfn.mice.1)), we actually run the missing value imputation. The built-in imputation methods are listed in the documentation. As we have numerical values in our peak table, we will only implement the following methods in the R script :
#     - __Mean__ (method = 'mean')
#     - __Simple random sampling__ (method = 'sample')
#     - __Classification and regression trees__ (method = 'cart')
#     - __Regression imputation__ (classified into two different versions: deterministic and stochastic regression imputation) :
#         - __Bayesian linear regression__ (method = "norm")
#         - __Deterministic regression imputation__ (method = "norm.predict") :
#             - replaces missing values with the exact prediction of the regression model. Random variation (i.e. an error term) around the regression slope is not considered. Imputed values are therefore often too precise and lead to an overestimation of the correlation between X and Y.
#         - __Stochastic regression imputation__ (method = "norm.nob") :
#             - was developed in order to solve this issue of deterministic regression imputation. Stochastic regression imputation adds a random error term to the predicted value and is therefore able to reproduce the correlation of X and Y more appropriately.
#     - __Predictive mean matching__ (method = "pmm") :
#         - Overcome disadvantages of regression imputation, implausible values (e.g. negative incomes) and problems with heteroscedastic data
#
# - using the <code>merge_imputations</code> method, we merge the multiple imputed dataframes into one single dataframe (mean of the multiple dataframes)
# - using the <code>write.csv</code> method, we export the imputed data into a separate csv file
# ---

# %%
# Set working directory
pathWorkDir = '/'.join(os.getcwd().split('/')[:-1])

# Set path to slurm script, R script, data and output
path2Rscript = pathWorkDir + '/bin/missing_value_imputation/mv_imp_MICE.R'
path2peakTable = pathWorkDir + '/data/peakTable/original_peak_table/peakTable_HILIC_POS.csv'
path2output = pathWorkDir + '/data/peakTable/imputed_peak_tables'
list_methods = 'c("mean","sample","pmm","cart","norm","norm.nob","norm.predict")' # all these methods should work
list_methods = "'".join(['', list_methods, ''])

# %% [markdown]
# # Launch missing value imputation with R

# %% [markdown]
# ## By launching the R script

# %%
! Rscript $path2Rscript $path2peakTable $path2output $list_methods
# Out:
# [1] "/home/lcolucci/Bureau/working_directory_genmed/project_data/Metabolomics-tutorial/ML_notebooks/data/peakTable/original_peak_table/peakTable_HILIC_POS.csv"
# [1] "/home/lcolucci/Bureau/working_directory_genmed/project_data/Metabolomics-tutorial/ML_notebooks/data/peakTable/imputed_peak_tables"
# [1] "c(\"mean\",\"sample\",\"pmm\",\"cart\",\"norm\",\"norm.nob\",\"norm.predict\")"
# [1] "mean"         "sample"       "pmm"          "cart"         "norm"
# [6] "norm.nob"     "norm.predict"
# Le chargement a nécessité le package : mice
#
# Attachement du package : ‘mice’
#
# The following object is masked from ‘package:stats’:
#
#     filter
#
# The following objects are masked from ‘package:base’:
#
#     cbind, rbind
#
# Le chargement a nécessité le package : sjmisc
# ----------------------------------------------------------------------------------------------------
# ----------------------------------------------- mean -----------------------------------------------
# ...Computing...
# ...............
# 1 min 36 sec
# ----------------------------------------------------------------------------------------------------
#
#
#
# ----------------------------------------------------------------------------------------------------
# ---------------------------------------------- sample ----------------------------------------------
# ...Computing...
# ...............
# 1 min 37 sec
# ----------------------------------------------------------------------------------------------------
#
#
#
# ----------------------------------------------------------------------------------------------------
# ----------------------------------------------- pmm ------------------------------------------------
# ...Computing...
# ...............
# 1 min 55 sec
# ----------------------------------------------------------------------------------------------------
#
#
#
# ----------------------------------------------------------------------------------------------------
# ----------------------------------------------- cart -----------------------------------------------
# ...Computing...
# ...............
# 2 min 58 sec
# ----------------------------------------------------------------------------------------------------
#
#
#
# ----------------------------------------------------------------------------------------------------
# ----------------------------------------------- norm -----------------------------------------------
# ...Computing...
# ...............
# 1 min 54 sec
# ----------------------------------------------------------------------------------------------------
#
#
#
# ----------------------------------------------------------------------------------------------------
# --------------------------------------------- norm.nob ---------------------------------------------
# ...Computing...
# ...............
# 1 min 57 sec
# ----------------------------------------------------------------------------------------------------
#
#
#
# ----------------------------------------------------------------------------------------------------
# ------------------------------------------- norm.predict -------------------------------------------
# ...Computing...
# ...............
# 1 min 54 sec
# ----------------------------------------------------------------------------------------------------
#
#
#
# Warning messages:
# 1: Number of logged events: 3940
# 2: Number of logged events: 3888
# 3: Number of logged events: 4040
# 4: Number of logged events: 4063
# 5: Number of logged events: 3993
# 6: Number of logged events: 4004
# 7: Number of logged events: 4045

# %%
MICE_mean = pd.read_csv(path_peakTable_imputed+'X_R_MICE_mean.csv')
MICE_sample = pd.read_csv(path_peakTable_imputed+'X_R_MICE_sample.csv')
MICE_pmm = pd.read_csv(path_peakTable_imputed+'X_R_MICE_pmm.csv')
MICE_cart = pd.read_csv(path_peakTable_imputed+'X_R_MICE_cart.csv')
MICE_norm = pd.read_csv(path_peakTable_imputed+'X_R_MICE_norm.csv')
MICE_norm_nob = pd.read_csv(path_peakTable_imputed+'X_R_MICE_norm_nob.csv')
MICE_norm_pred = pd.read_csv(path_peakTable_imputed+'X_R_MICE_norm_predict.csv')

# %%
MICE_mean
# Out:
#      variable_3  variable_5  variable_6  variable_7  variable_8  variable_10  \
# 0     19.761786   14.635833   22.185582   16.414744   12.615143    15.580604
# 1     19.735279   15.193396   20.831414   15.052533   12.520547    15.145423
# 2     19.116076   15.446714   22.152604   16.410827   12.520547    14.628890
# 3     19.376875   15.460525   22.169389   16.403964   12.720767    15.937169
# 4     19.555938   14.515536   22.150249   16.372219   12.314019    14.950203
# ..          ...         ...         ...         ...         ...          ...
# 181   19.664978   14.447858   20.808503   15.027154   12.648327    14.806952
# 182   19.301954   14.839941   21.085175   15.321075   12.510670    14.488147
# 183   19.170626   14.291711   21.381912   15.197205   12.499558    14.434959
# 184   18.869505   14.440576   20.961485   14.829978   12.312338    14.114074
# 185   18.954904   14.358631   20.005032   15.873984   12.414258    15.138143
#
#      variable_11  variable_14  variable_22  variable_23  ...  variable_2339  \
# 0      15.881437    17.500899    12.792893    16.805604  ...      12.052252
# 1      14.034654    17.953780    12.541715    15.907714  ...      13.020365
# 2      15.316772    17.404715    12.786407    15.947176  ...      12.750163
# 3      15.967749    15.836957    12.541715    16.371211  ...      12.750163
# 4      15.294906    16.610171    12.214057    16.171763  ...      12.750163
# ..           ...          ...          ...          ...  ...            ...
# 181    14.244917    17.126579    12.080710    15.388376  ...      12.349299
# 182    15.163197    16.816591    12.452644    16.474456  ...      12.909283
# 183    14.520558    16.315887    12.808417    15.613263  ...      12.846355
# 184    13.776358    16.110117    12.667428    16.021372  ...      12.477753
# 185    15.179461    15.432975    12.047361    15.443640  ...      13.225899
#
#      variable_2340  variable_2350  variable_2353  variable_2364  \
# 0        12.568647      13.192848      13.230752      12.248590
# 1        12.928643      13.697314      12.922436      12.604052
# 2        12.498674      13.112297      13.330175      12.252300
# 3        12.498674      13.086805      13.304171      12.252300
# 4        12.498674      13.112297      13.306722      12.349830
# ..             ...            ...            ...            ...
# 181      11.505004      13.189121      12.922436      12.252300
# 182      12.642143      13.112297      12.922436      12.708850
# 183      13.243400      13.112297      12.922436      12.199647
# 184      11.789382      13.112297      12.922436      11.628154
# 185      12.978890      11.596877      12.922436      12.252300
#
#      variable_2365  variable_2368  variable_2370  variable_2375  variable_2379
# 0        12.114328      14.269258      12.355017      13.114289      13.882526
# 1        12.083249      13.528211      12.208084      12.686433      13.244201
# 2        12.083249      14.215988      12.305932      12.955618      13.778398
# 3        11.605353      14.284148      12.319119      13.058285      13.812829
# 4        11.926237      14.192775      12.305932      13.006556      13.841201
# ..             ...            ...            ...            ...            ...
# 181      12.083249      13.528211      12.305932      12.686433      13.244201
# 182      12.462751      12.175110      12.635066      12.686433      13.244201
# 183      12.083249      13.528211      12.258149      12.686433      13.244201
# 184      12.083249      13.528211      12.305932      12.686433      13.244201
# 185      12.083249      13.528211      12.158923      12.686433      13.244201
#
# [186 rows x 557 columns]

# %%
MICE_sample
# Out:
#      variable_3  variable_5  variable_6  variable_7  variable_8  variable_10  \
# 0     19.761786   14.635833   22.185582   16.414744   12.615143    15.580604
# 1     19.735279   15.193396   20.831414   15.052533   12.534965    15.145423
# 2     19.116076   15.446714   22.152604   16.410827   12.390362    14.628890
# 3     19.376875   15.460525   22.169389   16.403964   12.720767    15.937169
# 4     19.555938   14.515536   22.150249   16.372219   12.314019    14.950203
# ..          ...         ...         ...         ...         ...          ...
# 181   19.664978   14.447858   20.808503   15.027154   12.648327    14.806952
# 182   19.301954   14.839941   21.085175   15.321075   12.510670    14.488147
# 183   19.170626   14.291711   21.381912   15.197205   12.499558    14.434959
# 184   18.869505   14.440576   20.961485   14.829978   12.312338    14.114074
# 185   18.954904   14.519395   20.005032   15.762084   12.414258    15.114542
#
#      variable_11  variable_14  variable_22  variable_23  ...  variable_2339  \
# 0      15.881437    17.500899    12.792893    16.805604  ...      12.052252
# 1      14.034654    17.953780    12.421543    15.907714  ...      13.020365
# 2      15.316772    17.404715    12.786407    15.947176  ...      12.638734
# 3      15.967749    15.836957    12.904245    16.371211  ...      12.434636
# 4      15.294906    16.610171    12.214057    16.171763  ...      12.829639
# ..           ...          ...          ...          ...  ...            ...
# 181    14.244917    17.126579    12.080710    15.388376  ...      12.349299
# 182    15.163197    16.816591    12.452644    16.474456  ...      12.909283
# 183    14.520558    16.315887    12.808417    15.613263  ...      12.846355
# 184    13.776358    16.110117    12.667428    16.021372  ...      12.477753
# 185    15.237133    15.432975    12.047361    15.443640  ...      13.225899
#
#      variable_2340  variable_2350  variable_2353  variable_2364  \
# 0        12.568647      13.192848      13.230752      12.248590
# 1        12.928643      13.697314      12.861214      12.604052
# 2        12.457304      12.811455      13.330175      12.279598
# 3        12.475331      13.086805      13.304171      12.493456
# 4        12.548877      12.728041      13.306722      12.349830
# ..             ...            ...            ...            ...
# 181      11.505004      13.189121      13.075684      12.353038
# 182      12.642143      13.174005      12.807708      12.708850
# 183      13.243400      12.973209      12.876049      12.199647
# 184      11.789382      13.009247      12.921498      11.628154
# 185      12.978890      11.596877      12.747928      12.229266
#
#      variable_2365  variable_2368  variable_2370  variable_2375  variable_2379
# 0        12.114328      14.269258      12.355017      13.114289      13.882526
# 1        11.985547      13.366798      12.208084      12.562046      13.234203
# 2        12.043493      14.215988      12.494990      12.955618      13.778398
# 3        11.605353      14.284148      12.319119      13.058285      13.812829
# 4        11.926237      14.192775      12.394620      13.006556      13.841201
# ..             ...            ...            ...            ...            ...
# 181      12.096139      13.358518      12.413215      12.546546      13.158065
# 182      12.462751      12.175110      12.635066      12.469638      13.596263
# 183      12.080858      13.677991      12.258149      12.877234      13.280590
# 184      11.998314      13.568009      12.218278      12.538345      13.057475
# 185      12.048745      13.765693      12.158923      12.750131      13.523223
#
# [186 rows x 557 columns]

# %%
MICE_pmm
# Out:
#      variable_3  variable_5  variable_6  variable_7  variable_8  variable_10  \
# 0     19.761786   14.635833   22.185582   16.414744   12.615143    15.580604
# 1     19.735279   15.193396   20.831414   15.052533   12.612824    15.145423
# 2     19.116076   15.446714   22.152604   16.410827   12.684692    14.628890
# 3     19.376875   15.460525   22.169389   16.403964   12.720767    15.937169
# 4     19.555938   14.515536   22.150249   16.372219   12.314019    14.950203
# ..          ...         ...         ...         ...         ...          ...
# 181   19.664978   14.447858   20.808503   15.027154   12.648327    14.806952
# 182   19.301954   14.839941   21.085175   15.321075   12.510670    14.488147
# 183   19.170626   14.291711   21.381912   15.197205   12.499558    14.434959
# 184   18.869505   14.440576   20.961485   14.829978   12.312338    14.114074
# 185   18.954904   13.659915   20.005032   15.293274   12.414258    13.161972
#
#      variable_11  variable_14  variable_22  variable_23  ...  variable_2339  \
# 0      15.881437    17.500899    12.792893    16.805604  ...      12.052252
# 1      14.034654    17.953780    11.972070    15.907714  ...      13.020365
# 2      15.316772    17.404715    12.786407    15.947176  ...      12.723511
# 3      15.967749    15.836957    11.914445    16.371211  ...      12.777079
# 4      15.294906    16.610171    12.214057    16.171763  ...      12.479423
# ..           ...          ...          ...          ...  ...            ...
# 181    14.244917    17.126579    12.080710    15.388376  ...      12.349299
# 182    15.163197    16.816591    12.452644    16.474456  ...      12.909283
# 183    14.520558    16.315887    12.808417    15.613263  ...      12.846355
# 184    13.776358    16.110117    12.667428    16.021372  ...      12.477753
# 185    13.037956    15.432975    12.047361    15.443640  ...      13.225899
#
#      variable_2340  variable_2350  variable_2353  variable_2364  \
# 0        12.568647      13.192848      13.230752      12.248590
# 1        12.928643      13.697314      11.767773      12.604052
# 2        12.338878      11.978020      13.330175      12.085444
# 3        12.417310      13.086805      13.304171      12.217361
# 4        12.373550      12.128220      13.306722      12.349830
# ..             ...            ...            ...            ...
# 181      11.505004      13.189121      11.779772      11.795892
# 182      12.642143      11.884585      11.851173      12.708850
# 183      13.243400      12.346116      11.813250      12.199647
# 184      11.789382      12.093942      11.794352      11.628154
# 185      12.978890      11.596877      11.875361      12.354711
#
#      variable_2365  variable_2368  variable_2370  variable_2375  variable_2379
# 0        12.114328      14.269258      12.355017      13.114289      13.882526
# 1        11.940738      12.081930      12.208084      11.658714      11.886234
# 2        12.033075      14.215988      12.137042      12.955618      13.778398
# 3        11.605353      14.284148      12.319119      13.058285      13.812829
# 4        11.926237      14.192775      12.103663      13.006556      13.841201
# ..             ...            ...            ...            ...            ...
# 181      11.740239      12.206182      11.929681      11.651316      11.757326
# 182      12.462751      12.175110      12.635066      11.682765      11.992139
# 183      12.229219      12.024187      12.258149      11.683022      11.833318
# 184      11.959119      12.123266      11.835645      11.702898      11.964187
# 185      12.095768      11.968548      12.158923      11.687586      11.985994
#
# [186 rows x 557 columns]

# %%
MICE_cart
# Out:
#      variable_3  variable_5  variable_6  variable_7  variable_8  variable_10  \
# 0     19.761786   14.635833   22.185582   16.414744   12.615143    15.580604
# 1     19.735279   15.193396   20.831414   15.052533   12.631515    15.145423
# 2     19.116076   15.446714   22.152604   16.410827   12.443183    14.628890
# 3     19.376875   15.460525   22.169389   16.403964   12.720767    15.937169
# 4     19.555938   14.515536   22.150249   16.372219   12.314019    14.950203
# ..          ...         ...         ...         ...         ...          ...
# 181   19.664978   14.447858   20.808503   15.027154   12.648327    14.806952
# 182   19.301954   14.839941   21.085175   15.321075   12.510670    14.488147
# 183   19.170626   14.291711   21.381912   15.197205   12.499558    14.434959
# 184   18.869505   14.440576   20.961485   14.829978   12.312338    14.114074
# 185   18.954904   14.185888   20.005032   14.672588   12.414258    13.149789
#
#      variable_11  variable_14  variable_22  variable_23  ...  variable_2339  \
# 0      15.881437    17.500899    12.792893    16.805604  ...      12.052252
# 1      14.034654    17.953780    11.966218    15.907714  ...      13.020365
# 2      15.316772    17.404715    12.786407    15.947176  ...      12.384017
# 3      15.967749    15.836957    11.884163    16.371211  ...      12.994184
# 4      15.294906    16.610171    12.214057    16.171763  ...      12.385035
# ..           ...          ...          ...          ...  ...            ...
# 181    14.244917    17.126579    12.080710    15.388376  ...      12.349299
# 182    15.163197    16.816591    12.452644    16.474456  ...      12.909283
# 183    14.520558    16.315887    12.808417    15.613263  ...      12.846355
# 184    13.776358    16.110117    12.667428    16.021372  ...      12.477753
# 185    12.769334    15.432975    12.047361    15.443640  ...      13.225899
#
#      variable_2340  variable_2350  variable_2353  variable_2364  \
# 0        12.568647      13.192848      13.230752      12.248590
# 1        12.928643      13.697314      12.046163      12.604052
# 2        12.164265      12.121874      13.330175      12.145722
# 3        12.304329      13.086805      13.304171      12.409727
# 4        12.162956      12.028878      13.306722      12.349830
# ..             ...            ...            ...            ...
# 181      11.505004      13.189121      11.913550      11.836250
# 182      12.642143      11.993084      11.861031      12.708850
# 183      13.243400      12.467013      12.008357      12.199647
# 184      11.789382      11.964734      12.123110      11.628154
# 185      12.978890      11.596877      12.002154      12.162470
#
#      variable_2365  variable_2368  variable_2370  variable_2375  variable_2379
# 0        12.114328      14.269258      12.355017      13.114289      13.882526
# 1        11.844769      12.137746      12.208084      11.681723      12.012793
# 2        12.021841      14.215988      12.017600      12.955618      13.778398
# 3        11.605353      14.284148      12.319119      13.058285      13.812829
# 4        11.926237      14.192775      12.137453      13.006556      13.841201
# ..             ...            ...            ...            ...            ...
# 181      11.946050      12.047852      11.958292      12.052891      12.114433
# 182      12.462751      12.175110      12.635066      11.834264      11.899315
# 183      12.382832      12.170335      12.258149      11.752856      11.900899
# 184      11.647248      12.581118      11.953485      12.018019      12.164984
# 185      12.193274      12.112991      12.158923      11.970871      12.220083
#
# [186 rows x 557 columns]

# %%
MICE_norm
# Out:
#      variable_3  variable_5  variable_6  variable_7  variable_8  variable_10  \
# 0     19.761786   14.635833   22.185582   16.414744   12.615143    15.580604
# 1     19.735279   15.193396   20.831414   15.052533   12.535163    15.145423
# 2     19.116076   15.446714   22.152604   16.410827   12.550822    14.628890
# 3     19.376875   15.460525   22.169389   16.403964   12.720767    15.937169
# 4     19.555938   14.515536   22.150249   16.372219   12.314019    14.950203
# ..          ...         ...         ...         ...         ...          ...
# 181   19.664978   14.447858   20.808503   15.027154   12.648327    14.806952
# 182   19.301954   14.839941   21.085175   15.321075   12.510670    14.488147
# 183   19.170626   14.291711   21.381912   15.197205   12.499558    14.434959
# 184   18.869505   14.440576   20.961485   14.829978   12.312338    14.114074
# 185   18.954904   12.424422   20.005032   13.750818   12.414258    11.272806
#
#      variable_11  variable_14  variable_22  variable_23  ...  variable_2339  \
# 0      15.881437    17.500899    12.792893    16.805604  ...      12.052252
# 1      14.034654    17.953780    12.119895    15.907714  ...      13.020365
# 2      15.316772    17.404715    12.786407    15.947176  ...      12.529996
# 3      15.967749    15.836957    11.878374    16.371211  ...      12.556218
# 4      15.294906    16.610171    12.214057    16.171763  ...      12.399904
# ..           ...          ...          ...          ...  ...            ...
# 181    14.244917    17.126579    12.080710    15.388376  ...      12.349299
# 182    15.163197    16.816591    12.452644    16.474456  ...      12.909283
# 183    14.520558    16.315887    12.808417    15.613263  ...      12.846355
# 184    13.776358    16.110117    12.667428    16.021372  ...      12.477753
# 185    11.890243    15.432975    12.047361    15.443640  ...      13.225899
#
#      variable_2340  variable_2350  variable_2353  variable_2364  \
# 0        12.568647      13.192848      13.230752      12.248590
# 1        12.928643      13.697314       9.725767      12.604052
# 2        12.153467      11.072842      13.330175      12.079122
# 3        12.470300      13.086805      13.304171      11.900468
# 4        12.031344      10.785179      13.306722      12.349830
# ..             ...            ...            ...            ...
# 181      11.505004      13.189121       9.679808      11.614133
# 182      12.642143      11.819473      11.156001      12.708850
# 183      13.243400      12.371851      10.731536      12.199647
# 184      11.789382      11.517556       9.575399      11.628154
# 185      12.978890      11.596877       5.166902      12.124627
#
#      variable_2365  variable_2368  variable_2370  variable_2375  variable_2379
# 0        12.114328      14.269258      12.355017      13.114289      13.882526
# 1        12.043482      11.317989      12.208084       9.269280      10.739572
# 2        11.863600      14.215988      12.122143      12.955618      13.778398
# 3        11.605353      14.284148      12.319119      13.058285      13.812829
# 4        11.926237      14.192775      12.173414      13.006556      13.841201
# ..             ...            ...            ...            ...            ...
# 181      11.767596      12.096188      11.699617       9.009019      11.078673
# 182      12.462751      12.175110      12.635066      10.511663      11.855567
# 183      12.180903      11.914117      12.258149       9.836511      11.490906
# 184      11.912365      11.783606      12.092662       8.748866      10.435400
# 185      11.986167       8.827292      12.158923       4.954119       7.997504
#
# [186 rows x 557 columns]

# %%
MICE_norm_nob
# Out:
#      variable_3  variable_5  variable_6  variable_7  variable_8  variable_10  \
# 0     19.761786   14.635833   22.185582   16.414744   12.615143    15.580604
# 1     19.735279   15.193396   20.831414   15.052533   12.656578    15.145423
# 2     19.116076   15.446714   22.152604   16.410827   12.395225    14.628890
# 3     19.376875   15.460525   22.169389   16.403964   12.720767    15.937169
# 4     19.555938   14.515536   22.150249   16.372219   12.314019    14.950203
# ..          ...         ...         ...         ...         ...          ...
# 181   19.664978   14.447858   20.808503   15.027154   12.648327    14.806952
# 182   19.301954   14.839941   21.085175   15.321075   12.510670    14.488147
# 183   19.170626   14.291711   21.381912   15.197205   12.499558    14.434959
# 184   18.869505   14.440576   20.961485   14.829978   12.312338    14.114074
# 185   18.954904   12.893696   20.005032   13.870236   12.414258    11.354778
#
#      variable_11  variable_14  variable_22  variable_23  ...  variable_2339  \
# 0      15.881437    17.500899    12.792893    16.805604  ...      12.052252
# 1      14.034654    17.953780    11.954246    15.907714  ...      13.020365
# 2      15.316772    17.404715    12.786407    15.947176  ...      12.747983
# 3      15.967749    15.836957    11.739162    16.371211  ...      12.747652
# 4      15.294906    16.610171    12.214057    16.171763  ...      12.476825
# ..           ...          ...          ...          ...  ...            ...
# 181    14.244917    17.126579    12.080710    15.388376  ...      12.349299
# 182    15.163197    16.816591    12.452644    16.474456  ...      12.909283
# 183    14.520558    16.315887    12.808417    15.613263  ...      12.846355
# 184    13.776358    16.110117    12.667428    16.021372  ...      12.477753
# 185    12.068515    15.432975    12.047361    15.443640  ...      13.225899
#
#      variable_2340  variable_2350  variable_2353  variable_2364  \
# 0        12.568647      13.192848      13.230752      12.248590
# 1        12.928643      13.697314       9.886609      12.604052
# 2        12.557387      11.134129      13.330175      12.079312
# 3        12.332701      13.086805      13.304171      12.149334
# 4        12.151411      10.850579      13.306722      12.349830
# ..             ...            ...            ...            ...
# 181      11.505004      13.189121       9.683314      11.673970
# 182      12.642143      11.814728      11.311282      12.708850
# 183      13.243400      12.429427      10.599106      12.199647
# 184      11.789382      11.601195       9.588775      11.628154
# 185      12.978890      11.596877       5.741115      12.179893
#
#      variable_2365  variable_2368  variable_2370  variable_2375  variable_2379
# 0        12.114328      14.269258      12.355017      13.114289      13.882526
# 1        12.260042      11.102198      12.208084       9.905912      10.757921
# 2        12.026381      14.215988      12.077919      12.955618      13.778398
# 3        11.605353      14.284148      12.319119      13.058285      13.812829
# 4        11.926237      14.192775      12.108694      13.006556      13.841201
# ..             ...            ...            ...            ...            ...
# 181      11.614928      11.888664      11.762059       9.705238      11.210008
# 182      12.462751      12.175110      12.635066      10.953242      11.846309
# 183      12.381119      11.968688      12.258149      10.422734      11.527146
# 184      11.807890      11.508896      12.245064       9.211643      10.703726
# 185      12.167663       8.666612      12.158923       7.065821       8.196679
#
# [186 rows x 557 columns]

# %%
MICE_norm_pred
# Out:
#      variable_3  variable_5  variable_6  variable_7  variable_8  variable_10  \
# 0     19.761786   14.635833   22.185582   16.414744   12.615143    15.580604
# 1     19.735279   15.193396   20.831414   15.052533   12.520547    15.145423
# 2     19.116076   15.446714   22.152604   16.410827   12.520547    14.628890
# 3     19.376875   15.460525   22.169389   16.403964   12.720767    15.937169
# 4     19.555938   14.515536   22.150249   16.372219   12.314019    14.950203
# ..          ...         ...         ...         ...         ...          ...
# 181   19.664978   14.447858   20.808503   15.027154   12.648327    14.806952
# 182   19.301954   14.839941   21.085175   15.321075   12.510670    14.488147
# 183   19.170626   14.291711   21.381912   15.197205   12.499558    14.434959
# 184   18.869505   14.440576   20.961485   14.829978   12.312338    14.114074
# 185   18.954904   12.943321   20.005032   13.845590   12.414258    11.319224
#
#      variable_11  variable_14  variable_22  variable_23  ...  variable_2339  \
# 0      15.881437    17.500899    12.792893    16.805604  ...      12.052252
# 1      14.034654    17.953780    12.006048    15.907714  ...      13.020365
# 2      15.316772    17.404715    12.786407    15.947176  ...      12.595198
# 3      15.967749    15.836957    11.827261    16.371211  ...      12.672596
# 4      15.294906    16.610171    12.214057    16.171763  ...      12.554922
# ..           ...          ...          ...          ...  ...            ...
# 181    14.244917    17.126579    12.080710    15.388376  ...      12.349299
# 182    15.163197    16.816591    12.452644    16.474456  ...      12.909283
# 183    14.520558    16.315887    12.808417    15.613263  ...      12.846355
# 184    13.776358    16.110117    12.667428    16.021372  ...      12.477753
# 185    12.154959    15.432975    12.047361    15.443640  ...      13.225899
#
#      variable_2340  variable_2350  variable_2353  variable_2364  \
# 0        12.568647      13.192848      13.230752      12.248590
# 1        12.928643      13.697314       9.991711      12.604052
# 2        12.344526      11.187842      13.330175      12.064193
# 3        12.408481      13.086805      13.304171      12.120211
# 4        12.311247      10.874560      13.306722      12.349830
# ..             ...            ...            ...            ...
# 181      11.505004      13.189121       9.926884      11.700665
# 182      12.642143      11.821375      11.364692      12.708850
# 183      13.243400      12.378418      10.794568      12.199647
# 184      11.789382      11.529765      10.017317      11.628154
# 185      12.978890      11.596877       6.800780      12.161591
#
#      variable_2365  variable_2368  variable_2370  variable_2375  variable_2379
# 0        12.114328      14.269258      12.355017      13.114289      13.882526
# 1        11.987353      11.186282      12.208084       9.722956      10.825733
# 2        11.935921      14.215988      12.152611      12.955618      13.778398
# 3        11.605353      14.284148      12.319119      13.058285      13.812829
# 4        11.926237      14.192775      12.061287      13.006556      13.841201
# ..             ...            ...            ...            ...            ...
# 181      11.768555      11.996612      11.868392       9.643587      11.139747
# 182      12.462751      12.175110      12.635066      10.805698      11.948253
# 183      12.307250      12.012354      12.258149      10.197573      11.594662
# 184      11.826172      11.760582      11.987848       9.066166      10.629827
# 185      12.053105       8.850355      12.158923       7.327943       8.059245
#
# [186 rows x 557 columns]

# %% [markdown]
# ### EXERCISE : comment the imputations
#
# Create one or several functions to __assess the imputation quality for each method used__.
#
# It could be interesting to find a __quantitative criterion__ and a __graphic representation__ to compare the quality of imputations.
#
# _Hint : a good imputation method should not change too much the distribution of feature values_-based Normalisation Methods

# %% [markdown]
# Based on your criterion and graphic outputs, which method(s) should be used on these data ?
#
# What are the common missing value imputation methods used in metabolomics (on LC-MS data in particular) ? Does it correspond to the "best" method(s) you found here ?

# %%
# We decided to take only the columns (metabolites) with no missing values to simulate missing values later.
# The following function has the objective of validating the explored imputation methods. 
# To do so, the function applies the analysed methods to a dataframe with simulated missing values to calculate 
# and plot the root mean square errors with respect to the exact values. 

def methods_validation (iterations):
    def my_mean (sample):
        return(sum(sample)/len(sample))
    
    const_0_val = []
    const_1_val = []
    mean_val = []
    mode_val = []
    median_val = []
    min_val = []
    half_min_val = []
    bay_val = []
    dec_tree_val = []
    ex_tree_val = []
    kneig_val = []
    knn_feat_val = []
    knn_samp_val = []
    R_mean_val = []
    R_sample_val = []
    R_pmm_val = []
    R_cart_val = []
    R_norm_val = []
    R_norm_nob_val = []
    R_norm_pred_val = []
    
    for i in range (iterations):
        
        subset = X.dropna(axis=1)
        subset_with_NaN = subset.copy() # copy subset that we will later fill with NaNs
        
        # Random substitution of 13% of the values in 'subset_with_NaN' with NaNs.
        # We keep 13% as NaNs percentage because it was the original value of NaNs. That represents 3696 values out of 29202.
        ix = [(row, col) for row in range(subset_with_NaN.shape[0]) for col in range(subset_with_NaN.shape[1])]
        for row, col in random.sample(ix, int(round(.13*len(ix)))):
            subset_with_NaN.iat[row, col] = np.nan


        # constant imputation
        
        subset_const_0 = const_imputer(subset_with_NaN)
        subset_const_0.to_csv(path_peakTable_imputed + 'subset_const_0.csv', index = False, header=True)
        mse_const_0 = sklearn.metrics.mean_squared_error(subset, subset_const_0)
        const_0_val.append (math.sqrt(mse_const_0))
        subset_const_1 = const_imputer(subset_with_NaN,1)
        subset_const_1.to_csv(path_peakTable_imputed + 'subset_const_1.csv', index = False, header=True)
        mse_const_1 = sklearn.metrics.mean_squared_error(subset, subset_const_1)
        const_1_val.append (math.sqrt(mse_const_1))
        
        # mean imputation    
        subset_mean = mean_imputer(subset_with_NaN)
        mse_mean = sklearn.metrics.mean_squared_error(subset, subset_mean)
        mean_val.append (math.sqrt(mse_mean))

        # median imputation
        subset_median = median_imputer(subset_with_NaN)
        mse_med = sklearn.metrics.mean_squared_error(subset, subset_median)
        median_val.append (math.sqrt(mse_med))


        # mode imputation
        subset_mode = mode_imputer(subset_with_NaN)
        mse_mode = sklearn.metrics.mean_squared_error(subset, subset_mode)
        mode_val.append (math.sqrt(mse_mode))


        # minimum imputation
        subset_min = min_imputer(subset_with_NaN)
        mse_min = sklearn.metrics.mean_squared_error(subset, subset_min)
        min_val.append(math.sqrt(mse_min))


        # half minimum imputation
        subset_half_min = half_min_imputer(subset_with_NaN)
        mse_half_min = sklearn.metrics.mean_squared_error(subset, subset_half_min)
        half_min_val.append(math.sqrt(mse_half_min))


        # multivariate imputation
        subset_multival = subset_with_NaN.copy()
        for estimator in estimators:
            subset_multival_MICE = python_MICE_imputer(subset_multival, estimator)
            subset_multival_MICE.to_csv(path_peakTable_imputed + 'subset_multival_MICE_' + str(estimator).split('(')[0] + '.csv', index = False, header=True)

        # Bayesian ridge imputation
        Bayesian_NaN = pd.read_csv(path_peakTable_imputed+'subset_multival_MICE_BayesianRidge.csv')
        mse_bay = sklearn.metrics.mean_squared_error(subset, Bayesian_NaN)
        bay_val.append (math.sqrt(mse_bay))

            # decision tree imputation
        Decision_tree_NaN = pd.read_csv(path_peakTable_imputed+'subset_multival_MICE_DecisionTreeRegressor.csv')
        mse_dec_tree = sklearn.metrics.mean_squared_error(subset, Decision_tree_NaN)
        dec_tree_val.append (math.sqrt(mse_dec_tree))

            #extra tree imputation
        Extra_tree_NaN = pd.read_csv(path_peakTable_imputed+'subset_multival_MICE_ExtraTreesRegressor.csv')
        mse_extra_tree = sklearn.metrics.mean_squared_error(subset, Extra_tree_NaN)
        ex_tree_val.append(math.sqrt(mse_extra_tree))

            #Kneighbor imputation
        K_neighbors_NaN = pd.read_csv(path_peakTable_imputed+'subset_multival_MICE_KNeighborsRegressor.csv')
        mse_kneig = sklearn.metrics.mean_squared_error(subset, K_neighbors_NaN)
        kneig_val.append(math.sqrt(mse_kneig))

        #nearest neighbor imputation
        subset_KNN_features = KNN_imputer(subset_with_NaN, by='features')
        subset_KNN_samples = KNN_imputer(subset_with_NaN, by='samples')
        mse_knn_feat = sklearn.metrics.mean_squared_error(subset, subset_KNN_features)
        knn_feat_val.append (math.sqrt(mse_knn_feat))
        mse_knn_samp = sklearn.metrics.mean_squared_error(subset, subset_KNN_samples)
        knn_samp_val.append(math.sqrt(mse_knn_samp))
        
        #R MICE imputation
        subset_R_mice = subset_with_NaN.copy()
        
        path_Rscr = pathWorkDir + '/bin/missing_value_imputation/mv_imp_MICE.R'
        path_test = pathWorkDir + '/data/peakTable/test_peak_tables/subset_R_mice.csv'
        path_test_imp = pathWorkDir + '/data/peakTable/test_imputed_peak_tables/'
        list_methods = 'c("mean","sample","pmm","cart","norm","norm.nob","norm.predict")'
        list_methods = "'".join(['', list_methods, ''])
        
        subset_R_mice.to_csv(path_test + 'subset_R_mice.csv', index = False, header=True)
        
        ! Rscript $path_Rscr $path_test $path_test_imp $list_methods
        
        subset_mice_mean = pd.read_csv(path_test_imp+'X_R_MICE_mean.csv')
        mse_mice_mean = sklearn.metrics.mean_squared_error(subset, subset_mice_mean)
        R_mean_val.append (math.sqrt(mse_mice_mean))
        
        subset_mice_sample = pd.read_csv(path_test_imp+'X_R_MICE_sample.csv')
        mse_mice_sample = sklearn.metrics.mean_squared_error(subset, subset_mice_sample)
        R_sample_val.append (math.sqrt(mse_mice_sample))
        
        subset_mice_pmm = pd.read_csv(path_test_imp+'X_R_MICE_pmm.csv')
        mse_mice_pmm = sklearn.metrics.mean_squared_error(subset, subset_mice_pmm)
        R_pmm_val.append (math.sqrt(mse_mice_pmm))
        
        subset_mice_cart = pd.read_csv(path_test_imp+'X_R_MICE_cart.csv')
        mse_mice_cart = sklearn.metrics.mean_squared_error(subset, subset_mice_cart)
        R_cart_val.append (math.sqrt(mse_mice_cart))
        
        subset_mice_norm = pd.read_csv(path_test_imp+'X_R_MICE_norm.csv')
        mse_mice_norm = sklearn.metrics.mean_squared_error(subset, subset_mice_norm)
        R_norm_val.append (math.sqrt(mse_mice_norm))
        
        subset_mice_norm_nob = pd.read_csv(path_test_imp+'X_R_MICE_norm_nob.csv')
        mse_mice_norm_nob = sklearn.metrics.mean_squared_error(subset, subset_mice_norm_nob)
        R_norm_nob_val.append (math.sqrt(mse_mice_norm_nob))
        
        subset_mice_norm_pred = pd.read_csv(path_test_imp+'X_R_MICE_norm_predict.csv')
        mse_mice_norm_pred = sklearn.metrics.mean_squared_error(subset, subset_mice_norm_pred)
        R_norm_pred_val.append (math.sqrt(mse_mice_norm_pred))
    
    const_0_hist = my_mean (const_0_val)
    const_1_hist = my_mean (const_1_val)
    mean_hist = my_mean (mean_val)
    median_hist = my_mean (median_val)
    mode_hist = my_mean (mode_val)
    min_hist = my_mean (min_val)
    half_min_hist = my_mean (half_min_val)
    bay_hist = my_mean (bay_val)
    dec_tree_hist = my_mean (dec_tree_val)
    ex_tree_hist = my_mean (ex_tree_val)
    kneigh_hist = my_mean (kneig_val)
    knn_feat_hist = my_mean (knn_feat_val)
    knn_samp_hist = my_mean (knn_samp_val)
    R_mean_hist = my_mean (R_mean_val)
    R_sample_hist = my_mean (R_sample_val)
    R_pmm_hist = my_mean (R_pmm_val)
    R_cart_hist = my_mean (R_cart_val)
    R_norm_hist = my_mean (R_norm_val)
    R_norm_nob_hist = my_mean (R_norm_nob_val)
    R_norm_pred_hist = my_mean (R_norm_pred_val)
    
    
    #bar diagram
    methods = ['Constant 0','Constant 1','Mean','Median','Mode','Minimum','Half Minimum','Bayesian Ridge','Decision Tree Regression','Extra Tree Regression','K-neighbor','N-neighbor by features','N-neighbor by samples','R-mice_mean','R-mice_sample','R-mice_pmm','R-mice_cart','R-mice_norm','R-mice_norm-nob','R-mice_norm-pred']
    data = [const_0_hist,const_1_hist,mean_hist,median_hist,mode_hist,min_hist,half_min_hist,bay_hist, dec_tree_hist,ex_tree_hist,kneigh_hist,knn_feat_hist,knn_samp_hist,R_mean_hist,R_sample_hist,R_pmm_hist,R_cart_hist,R_norm_hist,R_norm_nob_hist,R_norm_pred_hist]
    
    fig, ax = plt.subplots(figsize = (24,10))

    num = 20
    ind = np.arange (num)
    plt.figure(figsize=(24,10))
    bars = ax.bar(ind, data, align='center')
    ax.set_xticks(ind, labels=methods, rotation = 'vertical')
    ax.set_ylabel('RMSE')
    ax.set_title('Methods evaluation')

    ax.bar_label(bars, fmt='%.3f') 

    return (plt.show())

# %%
methods_validation(5)
# Out:
# /opt/anaconda3/lib/python3.7/site-packages/sklearn/impute/_iterative.py:701: ConvergenceWarning: [IterativeImputer] Early stopping criterion not reached.
#   ConvergenceWarning,
# ----- 2.1 seconds -----
# /opt/anaconda3/lib/python3.7/site-packages/sklearn/impute/_iterative.py:701: ConvergenceWarning: [IterativeImputer] Early stopping criterion not reached.
#   ConvergenceWarning,
# ----- 1.7 seconds -----
# /opt/anaconda3/lib/python3.7/site-packages/sklearn/impute/_iterative.py:701: ConvergenceWarning: [IterativeImputer] Early stopping criterion not reached.
#   ConvergenceWarning,
# ----- 15.5 seconds -----
# /opt/anaconda3/lib/python3.7/site-packages/sklearn/impute/_iterative.py:701: ConvergenceWarning: [IterativeImputer] Early stopping criterion not reached.
#   ConvergenceWarning,
# ----- 2.3 seconds -----
# [1] "/home/lcolucci/Bureau/working_directory_genmed/project_data/Metabolomics-tutorial/ML_notebooks/data/peakTable/test_peak_tables/subset_R_mice.csv"
# [1] "/home/lcolucci/Bureau/working_directory_genmed/project_data/Metabolomics-tutorial/ML_notebooks/data/peakTable/test_imputed_peak_tables/"
# [1] "c(\"mean\",\"sample\",\"pmm\",\"cart\",\"norm\",\"norm.nob\",\"norm.predict\")"
# [1] "mean"         "sample"       "pmm"          "cart"         "norm"
# [6] "norm.nob"     "norm.predict"
# Le chargement a nécessité le package : mice
#
# Attachement du package : ‘mice’
#
# The following object is masked from ‘package:stats’:
#
#     filter
#
# The following objects are masked from ‘package:base’:
#
#     cbind, rbind
#
# Le chargement a nécessité le package : sjmisc
# ----------------------------------------------------------------------------------------------------
# ----------------------------------------------- mean -----------------------------------------------
# ...Computing...
# ...............
# 12 min 38 sec
# ----------------------------------------------------------------------------------------------------
#
#
#
# ----------------------------------------------------------------------------------------------------
# ---------------------------------------------- sample ----------------------------------------------
# ...Computing...
# ...............
# 12 min 12 sec
# ----------------------------------------------------------------------------------------------------
#
#
#
# ----------------------------------------------------------------------------------------------------
# ----------------------------------------------- pmm ------------------------------------------------
# ...Computing...
# ...............
# 15 min 41 sec
# ----------------------------------------------------------------------------------------------------
#
#
#
# ----------------------------------------------------------------------------------------------------
# ----------------------------------------------- cart -----------------------------------------------
# ...Computing...
# ...............
# 36 min 16 sec
# ----------------------------------------------------------------------------------------------------
#
#
#
# ----------------------------------------------------------------------------------------------------
# ----------------------------------------------- norm -----------------------------------------------
# ...Computing...
# ...............
# 15 min 46 sec
# ----------------------------------------------------------------------------------------------------
#
#
#
# ----------------------------------------------------------------------------------------------------
# --------------------------------------------- norm.nob ---------------------------------------------
# ...Computing...
# ...............
# 15 min 58 sec
# ----------------------------------------------------------------------------------------------------
#
#
#
# ----------------------------------------------------------------------------------------------------
# ------------------------------------------- norm.predict -------------------------------------------
# ...Computing...
# ...............
# 16 min 24 sec
# ----------------------------------------------------------------------------------------------------
#
#
#
# Warning messages:
# 1: Number of logged events: 1195
# 2: Number of logged events: 803
# 3: Number of logged events: 1394
# 4: Number of logged events: 1387
# 5: Number of logged events: 1580
# /opt/anaconda3/lib/python3.7/site-packages/sklearn/impute/_iterative.py:701: ConvergenceWarning: [IterativeImputer] Early stopping criterion not reached.
#   ConvergenceWarning,
# ----- 2.1 seconds -----
# /opt/anaconda3/lib/python3.7/site-packages/sklearn/impute/_iterative.py:701: ConvergenceWarning: [IterativeImputer] Early stopping criterion not reached.
#   ConvergenceWarning,
# ----- 1.7 seconds -----
# /opt/anaconda3/lib/python3.7/site-packages/sklearn/impute/_iterative.py:701: ConvergenceWarning: [IterativeImputer] Early stopping criterion not reached.
#   ConvergenceWarning,
# ----- 15.5 seconds -----
# /opt/anaconda3/lib/python3.7/site-packages/sklearn/impute/_iterative.py:701: ConvergenceWarning: [IterativeImputer] Early stopping criterion not reached.
#   ConvergenceWarning,
# ----- 2.3 seconds -----
# [1] "/home/lcolucci/Bureau/working_directory_genmed/project_data/Metabolomics-tutorial/ML_notebooks/data/peakTable/test_peak_tables/subset_R_mice.csv"
# [1] "/home/lcolucci/Bureau/working_directory_genmed/project_data/Metabolomics-tutorial/ML_notebooks/data/peakTable/test_imputed_peak_tables/"
# [1] "c(\"mean\",\"sample\",\"pmm\",\"cart\",\"norm\",\"norm.nob\",\"norm.predict\")"
# [1] "mean"         "sample"       "pmm"          "cart"         "norm"
# [6] "norm.nob"     "norm.predict"
# Le chargement a nécessité le package : mice
#
# Attachement du package : ‘mice’
#
# The following object is masked from ‘package:stats’:
#
#     filter
#
# The following objects are masked from ‘package:base’:
#
#     cbind, rbind
#
# Le chargement a nécessité le package : sjmisc
# ----------------------------------------------------------------------------------------------------
# ----------------------------------------------- mean -----------------------------------------------
# ...Computing...
# ...............
# 12 min 28 sec
# ----------------------------------------------------------------------------------------------------
#
#
#
# ----------------------------------------------------------------------------------------------------
# ---------------------------------------------- sample ----------------------------------------------
# ...Computing...
# ...............
# 12 min 19 sec
# ----------------------------------------------------------------------------------------------------
#
#
#
# ----------------------------------------------------------------------------------------------------
# ----------------------------------------------- pmm ------------------------------------------------
# ...Computing...
# ...............
# 15 min 40 sec
# ----------------------------------------------------------------------------------------------------
#
#
#
# ----------------------------------------------------------------------------------------------------
# ----------------------------------------------- cart -----------------------------------------------
# ...Computing...
# ...............
# 36 min 20 sec
# ----------------------------------------------------------------------------------------------------
#
#
#
# ----------------------------------------------------------------------------------------------------
# ----------------------------------------------- norm -----------------------------------------------
# ...Computing...
# ...............
# 15 min 50 sec
# ----------------------------------------------------------------------------------------------------
#
#
#
# ----------------------------------------------------------------------------------------------------
# --------------------------------------------- norm.nob ---------------------------------------------
# ...Computing...
# ...............
# 15 min 37 sec
# ----------------------------------------------------------------------------------------------------
#
#
#
# ----------------------------------------------------------------------------------------------------
# ------------------------------------------- norm.predict -------------------------------------------
# ...Computing...
# ...............
# 16 min 27 sec
# ----------------------------------------------------------------------------------------------------
#
#
#
# Warning messages:
# 1: Number of logged events: 1195
# 2: Number of logged events: 803
# 3: Number of logged events: 1394
# 4: Number of logged events: 1387
# 5: Number of logged events: 1580
# /opt/anaconda3/lib/python3.7/site-packages/sklearn/impute/_iterative.py:701: ConvergenceWarning: [IterativeImputer] Early stopping criterion not reached.
#   ConvergenceWarning,
# ----- 2.1 seconds -----
# /opt/anaconda3/lib/python3.7/site-packages/sklearn/impute/_iterative.py:701: ConvergenceWarning: [IterativeImputer] Early stopping criterion not reached.
#   ConvergenceWarning,
# ----- 1.8 seconds -----
# /opt/anaconda3/lib/python3.7/site-packages/sklearn/impute/_iterative.py:701: ConvergenceWarning: [IterativeImputer] Early stopping criterion not reached.
#   ConvergenceWarning,
# ----- 15.4 seconds -----
# /opt/anaconda3/lib/python3.7/site-packages/sklearn/impute/_iterative.py:701: ConvergenceWarning: [IterativeImputer] Early stopping criterion not reached.
#   ConvergenceWarning,
# ----- 2.3 seconds -----
# [1] "/home/lcolucci/Bureau/working_directory_genmed/project_data/Metabolomics-tutorial/ML_notebooks/data/peakTable/test_peak_tables/subset_R_mice.csv"
# [1] "/home/lcolucci/Bureau/working_directory_genmed/project_data/Metabolomics-tutorial/ML_notebooks/data/peakTable/test_imputed_peak_tables/"
# [1] "c(\"mean\",\"sample\",\"pmm\",\"cart\",\"norm\",\"norm.nob\",\"norm.predict\")"
# [1] "mean"         "sample"       "pmm"          "cart"         "norm"
# [6] "norm.nob"     "norm.predict"
# Le chargement a nécessité le package : mice
#
# Attachement du package : ‘mice’
#
# The following object is masked from ‘package:stats’:
#
#     filter
#
# The following objects are masked from ‘package:base’:
#
#     cbind, rbind
#
# Le chargement a nécessité le package : sjmisc
# ----------------------------------------------------------------------------------------------------
# ----------------------------------------------- mean -----------------------------------------------
# ...Computing...
# ...............
# 12 min 34 sec
# ----------------------------------------------------------------------------------------------------
#
#
#
# ----------------------------------------------------------------------------------------------------
# ---------------------------------------------- sample ----------------------------------------------
# ...Computing...
# ...............
# 12 min 12 sec
# ----------------------------------------------------------------------------------------------------
#
#
#
# ----------------------------------------------------------------------------------------------------
# ----------------------------------------------- pmm ------------------------------------------------
# ...Computing...
# ...............
# 15 min 49 sec
# ----------------------------------------------------------------------------------------------------
#
#
#
# ----------------------------------------------------------------------------------------------------
# ----------------------------------------------- cart -----------------------------------------------
# ...Computing...
# ...............
# 36 min 29 sec
# ----------------------------------------------------------------------------------------------------
#
#
#
# ----------------------------------------------------------------------------------------------------
# ----------------------------------------------- norm -----------------------------------------------
# ...Computing...
# ...............
# 15 min 46 sec
# ----------------------------------------------------------------------------------------------------
#
#
#
# ----------------------------------------------------------------------------------------------------
# --------------------------------------------- norm.nob ---------------------------------------------
# ...Computing...
# ...............
# 15 min 41 sec
# ----------------------------------------------------------------------------------------------------
#
#
#
# ----------------------------------------------------------------------------------------------------
# ------------------------------------------- norm.predict -------------------------------------------
# ...Computing...
# ...............
# 16 min 22 sec
# ----------------------------------------------------------------------------------------------------
#
#
#
# Warning messages:
# 1: Number of logged events: 1195
# 2: Number of logged events: 803
# 3: Number of logged events: 1394
# 4: Number of logged events: 1387
# 5: Number of logged events: 1580
# /opt/anaconda3/lib/python3.7/site-packages/sklearn/impute/_iterative.py:701: ConvergenceWarning: [IterativeImputer] Early stopping criterion not reached.
#   ConvergenceWarning,
# ----- 2.0 seconds -----
# /opt/anaconda3/lib/python3.7/site-packages/sklearn/impute/_iterative.py:701: ConvergenceWarning: [IterativeImputer] Early stopping criterion not reached.
#   ConvergenceWarning,
# ----- 1.7 seconds -----
# /opt/anaconda3/lib/python3.7/site-packages/sklearn/impute/_iterative.py:701: ConvergenceWarning: [IterativeImputer] Early stopping criterion not reached.
#   ConvergenceWarning,
# ----- 15.4 seconds -----
# /opt/anaconda3/lib/python3.7/site-packages/sklearn/impute/_iterative.py:701: ConvergenceWarning: [IterativeImputer] Early stopping criterion not reached.
#   ConvergenceWarning,
# ----- 2.3 seconds -----
# [1] "/home/lcolucci/Bureau/working_directory_genmed/project_data/Metabolomics-tutorial/ML_notebooks/data/peakTable/test_peak_tables/subset_R_mice.csv"
# [1] "/home/lcolucci/Bureau/working_directory_genmed/project_data/Metabolomics-tutorial/ML_notebooks/data/peakTable/test_imputed_peak_tables/"
# [1] "c(\"mean\",\"sample\",\"pmm\",\"cart\",\"norm\",\"norm.nob\",\"norm.predict\")"
# [1] "mean"         "sample"       "pmm"          "cart"         "norm"
# [6] "norm.nob"     "norm.predict"
# Le chargement a nécessité le package : mice
#
# Attachement du package : ‘mice’
#
# The following object is masked from ‘package:stats’:
#
#     filter
#
# The following objects are masked from ‘package:base’:
#
#     cbind, rbind
#
# Le chargement a nécessité le package : sjmisc
# ----------------------------------------------------------------------------------------------------
# ----------------------------------------------- mean -----------------------------------------------
# ...Computing...
# ...............
# 12 min 30 sec
# ----------------------------------------------------------------------------------------------------
#
#
#
# ----------------------------------------------------------------------------------------------------
# ---------------------------------------------- sample ----------------------------------------------
# ...Computing...
# ...............
# 12 min 22 sec
# ----------------------------------------------------------------------------------------------------
#
#
#
# ----------------------------------------------------------------------------------------------------
# ----------------------------------------------- pmm ------------------------------------------------
# ...Computing...
# ...............
# 15 min 36 sec
# ----------------------------------------------------------------------------------------------------
#
#
#
# ----------------------------------------------------------------------------------------------------
# ----------------------------------------------- cart -----------------------------------------------
# ...Computing...
# ...............
# 36 min 33 sec
# ----------------------------------------------------------------------------------------------------
#
#
#
# ----------------------------------------------------------------------------------------------------
# ----------------------------------------------- norm -----------------------------------------------
# ...Computing...
# ...............
# 15 min 34 sec
# ----------------------------------------------------------------------------------------------------
#
#
#
# ----------------------------------------------------------------------------------------------------
# --------------------------------------------- norm.nob ---------------------------------------------
# ...Computing...
# ...............
# 15 min 38 sec
# ----------------------------------------------------------------------------------------------------
#
#
#
# ----------------------------------------------------------------------------------------------------
# ------------------------------------------- norm.predict -------------------------------------------
# ...Computing...
# ...............
# 16 min 29 sec
# ----------------------------------------------------------------------------------------------------
#
#
#
# Warning messages:
# 1: Number of logged events: 1195
# 2: Number of logged events: 803
# 3: Number of logged events: 1394
# 4: Number of logged events: 1387
# 5: Number of logged events: 1580
# /opt/anaconda3/lib/python3.7/site-packages/sklearn/impute/_iterative.py:701: ConvergenceWarning: [IterativeImputer] Early stopping criterion not reached.
#   ConvergenceWarning,
# ----- 2.1 seconds -----
# /opt/anaconda3/lib/python3.7/site-packages/sklearn/impute/_iterative.py:701: ConvergenceWarning: [IterativeImputer] Early stopping criterion not reached.
#   ConvergenceWarning,
# ----- 1.8 seconds -----
# /opt/anaconda3/lib/python3.7/site-packages/sklearn/impute/_iterative.py:701: ConvergenceWarning: [IterativeImputer] Early stopping criterion not reached.
#   ConvergenceWarning,
# ----- 15.7 seconds -----
# /opt/anaconda3/lib/python3.7/site-packages/sklearn/impute/_iterative.py:701: ConvergenceWarning: [IterativeImputer] Early stopping criterion not reached.
#   ConvergenceWarning,
# ----- 2.3 seconds -----
# [1] "/home/lcolucci/Bureau/working_directory_genmed/project_data/Metabolomics-tutorial/ML_notebooks/data/peakTable/test_peak_tables/subset_R_mice.csv"
# [1] "/home/lcolucci/Bureau/working_directory_genmed/project_data/Metabolomics-tutorial/ML_notebooks/data/peakTable/test_imputed_peak_tables/"
# [1] "c(\"mean\",\"sample\",\"pmm\",\"cart\",\"norm\",\"norm.nob\",\"norm.predict\")"
# [1] "mean"         "sample"       "pmm"          "cart"         "norm"
# [6] "norm.nob"     "norm.predict"
# Le chargement a nécessité le package : mice
#
# Attachement du package : ‘mice’
#
# The following object is masked from ‘package:stats’:
#
#     filter
#
# The following objects are masked from ‘package:base’:
#
#     cbind, rbind
#
# Le chargement a nécessité le package : sjmisc
# ----------------------------------------------------------------------------------------------------
# ----------------------------------------------- mean -----------------------------------------------
# ...Computing...
# ...............
# 12 min 31 sec
# ----------------------------------------------------------------------------------------------------
#
#
#
# ----------------------------------------------------------------------------------------------------
# ---------------------------------------------- sample ----------------------------------------------
# ...Computing...
# ...............
# 12 min 19 sec
# ----------------------------------------------------------------------------------------------------
#
#
#
# ----------------------------------------------------------------------------------------------------
# ----------------------------------------------- pmm ------------------------------------------------
# ...Computing...
# ...............
# 15 min 58 sec
# ----------------------------------------------------------------------------------------------------
#
#
#
# ----------------------------------------------------------------------------------------------------
# ----------------------------------------------- cart -----------------------------------------------
# ...Computing...
# ...............
# 37 min 7 sec
# ----------------------------------------------------------------------------------------------------
#
#
#
# ----------------------------------------------------------------------------------------------------
# ----------------------------------------------- norm -----------------------------------------------
# ...Computing...
# ...............
# 16 min 21 sec
# ----------------------------------------------------------------------------------------------------
#
#
#
# ----------------------------------------------------------------------------------------------------
# --------------------------------------------- norm.nob ---------------------------------------------
# ...Computing...
# ...............
# 16 min 16 sec
# ----------------------------------------------------------------------------------------------------
#
#
#
# ----------------------------------------------------------------------------------------------------
# ------------------------------------------- norm.predict -------------------------------------------
# ...Computing...
# ...............
# 16 min 45 sec
# ----------------------------------------------------------------------------------------------------
#
#
#
# Warning messages:
# 1: Number of logged events: 1195
# 2: Number of logged events: 803
# 3: Number of logged events: 1394
# 4: Number of logged events: 1387
# 5: Number of logged events: 1580

# %%
a = 1
b = 2
c = 3
data = {'a': a, 'b': b, 'c': c}
min(data, key=data.get)
'a'
